# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Had to install pip to get the geopy package
from geopy.geocoders import Nominatim

# %% [markdown]
# Here I'm taking only the rows that have a longitude or latitude within the area of frog sightings:

# %%
# Identifying the area our data spans across
frog_csv = pd.read_csv("frog_data.csv")
print( "The maximum latitude is: ", humidity_data["Latitude"].max())
print( "The minimum latitude is: ", humidity_data["Latitude"].min())
print( "The maximum longitude is: ", humidity_data["Longitude"].max())
print( "The maximum longitude is: ", humidity_data["Longitude"].min())
# Out:
# The maximum latitude is:  -37.01971
# The minimum latitude is:  -39.073162
# The maximum longitude is:  146.42387
# The maximum longitude is:  143.55423

# %%
mean_humidity_data = pd.read_csv("mean_humidity.csv")
print("With all locations the shape of the dataframe is: ", mean_humidity_data.shape)
# Out:
# With all locations the shape of the dataframe is:  (4160, 27)

# %%
# Obtaining the humidity data within the area of our data
relevant_humidity_data = humidity_data.loc[(mean_humidity_data["LAT"] >= -39.073162) & (mean_humidity_data["LAT"] <= -37.01971) &
                                          (mean_humidity_data["LON"] >= 143.55423) & (mean_humidity_data["LON"] <= 146.42387)]
print("With only relevant locations the shaope of the dataframe is: ", relevant_humidity_data.shape)
# Out:
# With only relevant locations the shaope of the dataframe is:  (208, 27)

# %%
mean_temp_data = pd.read_csv("temp_data.csv")
print("With all locations the shape of the dataframe is: ", mean_temp_data.shape)
# Out:
# With all locations the shape of the dataframe is:  (11648, 27)

# %%
# Obtaining the temperature data within the area of our data
relevant_temp_data =  mean_temp_data.loc[( mean_temp_data["LAT"] >= -39.073162) & ( mean_temp_data["LAT"] <= -37.01971) &
                                          ( mean_temp_data["LON"] >= 143.55423) & ( mean_temp_data["LON"] <= 146.42387)]
print("With only relevant locations the shaope of the dataframe is: ", relevant_temp_data.shape)
# Out:
# With only relevant locations the shaope of the dataframe is:  (208, 27)

# %%
# Out:
#            STATION_NAME  STN_ID    LAT     LON ENSEMBLE    RCP       MODEL  \
# 21        LAVERTON-RAAF   87031 -37.86  144.76   r1i1p1  rcp26  CESM1-CAM5
# 24    MELBOURNE-AIRPORT   86282 -37.68  144.84   r1i1p1  rcp26  CESM1-CAM5
# 61        LAVERTON-RAAF   87031 -37.86  144.76   r1i1p1  rcp26  CESM1-CAM5
# 64    MELBOURNE-AIRPORT   86282 -37.68  144.84   r1i1p1  rcp26  CESM1-CAM5
# 101       LAVERTON-RAAF   87031 -37.86  144.76   r1i1p1  rcp26  CESM1-CAM5
# ...                 ...     ...    ...     ...      ...    ...         ...
# 4064  MELBOURNE-AIRPORT   86282 -37.68  144.84   r1i1p1  rcp85   NorESM1-M
# 4101      LAVERTON-RAAF   87031 -37.86  144.76   r1i1p1  rcp85   NorESM1-M
# 4104  MELBOURNE-AIRPORT   86282 -37.68  144.84   r1i1p1  rcp85   NorESM1-M
# 4141      LAVERTON-RAAF   87031 -37.86  144.76   r1i1p1  rcp85   NorESM1-M
# 4144  MELBOURNE-AIRPORT   86282 -37.68  144.84   r1i1p1  rcp85   NorESM1-M
#
#      CLIMATOLOGY  Annual    DJF  ...  humidity 3  humidity 4  humidity 5  \
# 21     2020-2039   72.72  66.36  ...       72.48       73.72       81.13
# 24     2020-2039   71.02  65.01  ...       71.53       71.28       78.67
# 61     2040-2059   72.68  66.18  ...       73.96       73.74       80.47
# 64     2040-2059   70.91  64.68  ...       73.04       71.29       78.00
# 101    2060-2079   71.86  64.53  ...       72.10       72.22       80.81
# ...          ...     ...    ...  ...         ...         ...         ...
# 4064   2040-2059   71.18  66.45  ...       69.50       69.89       78.68
# 4101   2060-2079   72.86  67.87  ...       71.45       73.32       80.43
# 4104   2060-2079   71.17  66.68  ...       70.30       70.72       77.98
# 4141   2080-2099   72.74  68.61  ...       71.98       73.71       80.26
# 4144   2080-2099   70.97  67.32  ...       70.55       71.00       77.84
#
#       humidity 6  humidity 7  humidity 8  humidity 9  humidity 10  \
# 21         81.64       82.60       77.48       72.21        66.25
# 24         79.75       79.99       74.83       70.62        65.13
# 61         81.72       82.67       77.46       71.17        66.42
# 64         79.78       80.03       74.67       69.56        65.22
# 101        81.95       82.16       77.31       71.21        65.69
# ...          ...         ...         ...         ...          ...
# 4064       80.61       79.57       74.40       71.26        64.09
# 4101       82.24       82.04       76.45       72.46        65.32
# 4104       80.39       79.49       73.84       70.80        64.19
# 4141       82.25       80.99       76.71       71.98        64.86
# 4144       80.26       78.48       74.01       70.19        63.69
#
#       humidity 11  humidity 12
# 21          65.84        63.56
# 24          65.19        61.90
# 61          65.86        64.28
# 64          65.04        62.70
# 101         65.05        62.38
# ...           ...          ...
# 4064        66.54        65.59
# 4101        66.76        67.14
# 4104        66.01        65.75
# 4141        65.57        66.56
# 4144        64.87        65.08
#
# [208 rows x 27 columns]
