# %%
# Importing packages
import pandas as pd, numpy as np, csv
pd.set_option('display.max_columns', None)

# %%
# Importing file
order_name = input("Please enter the file name here:") 
order_name = order_name + ".csv"
address = "C:\\Users\\Dylan Rohan\\Downloads\\" + order_name
orders_df = pd.read_csv(address)

# Taking Pending orders
pending_df = orders_df[orders_df["Lineitem fulfillment status"] == "pending"].copy()

# Compiling orders
item_counts = pending_df['Order ID'].value_counts()
pending_df["Items ordered"] = pending_df['Order ID'].map(item_counts)
pending_df = pending_df[pending_df["Financial Status"]== "PAID"]

# Removing invoices
pending_df = pending_df[~pending_df['Lineitem sku'].astype(str).str.startswith('CUSTOM')]
# Out:
# Please enter the file name here:orders (8)

# %%
template_df = pd.read_excel('template.xlsx')
#template_df.columns

# %%
def compile_order_items(order_id, dataframe):
    order = dataframe[dataframe['Order ID'] == order_id]
    items = []
    for item in order['Lineitem name']:
        items.append(item)
    return items

#Test
#print(f"order 1361 contains:\n {compile_order_items(1847, orders_df)}")

# %%
# Compiling order and removing empty rows
orders_df["all contents"] = orders_df["Order ID"].map(lambda x: compile_order_items(x, orders_df))

# Obtaining only pending orders
pending_df = orders_df[orders_df["Fulfillment Status"] == 'pending'].copy()

# %%
# Checking available items
all_inventory = orders_df['Lineitem name'].unique()
for item in all_inventory:
    print(item)
# Out:
# Evangeline & Anura Crewneck
# Different not Less Beanie

# %%
# Initialize a dictionary to store item classes
class Item:
    def __init__(self, name, length, width, height, weight, material, description, hs_tarrif, value):
        self.name = name
        self.length = length
        self.width = width
        self.height = height
        self.weight = weight
        self.material = material
        self.description = description
        self.hs_tariff = hs_tarrif
        self.value = value
        
    
inventory = []
# Replace 'your_file.csv' with the path to your CSV file
with open('inventory_properties.csv', 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    # Skip the header row if it exists
    next(csv_reader, None)

    for row in csv_reader:
        # Item	Length	Width	Height	Weight	Material	Description	Hs tarrif value
        item = Item(str(row[0]), str(row[1]), str(row[2]), str(row[3]), str(row[4]), 
                    str(row[5]), str(row[6]), str(row[7]), str(row[8]))
        inventory.append(item)

# %%
# Gathering package properties 
def package_properties(package_contents):
        length = 0
        width = 0
        height = 0
        weight = 0
        description = []
        
        for element in package_contents:
            for item in inventory:
                if item.name == element:                 # If the item in the order matches the name in the inventory list
                    height += float(item.height)           # Sum it's height
                    weight += float(item.weight)            # ... it's weight
                
                    if length < float(item.length):        # take the largest length
                        length = float(item.length)        
                    if width < float(item.width):          # and the widest width
                        width = float(item.width)           
                    description.append(str(item.description)) # and adds the item to the package description
        
        return length, width, height, (round(weight,2) + 0.01), description

# %%
# Create new columns in the orders_df DataFrame
pending_df['package length'] = pending_df['all contents'].apply(lambda x: package_properties(x)[0])
pending_df['package width'] = pending_df['all contents'].apply(lambda x: package_properties(x)[1])
pending_df['package height'] = pending_df['all contents'].apply(lambda x: package_properties(x)[2])
pending_df['package weight'] = pending_df['all contents'].apply(lambda x: package_properties(x)[3])
pending_df['package description'] = pending_df['all contents'].apply(lambda x: package_properties(x)[4])

# %%
# Constant
pending_df["Send From Name"] = "Chloe Hayden ltd pty"
pending_df["Send From Business Name"] = "Chloe Hayden"
pending_df["Send From Address Line 1"] = "PO BOX 137"
pending_df["Send From Address Line 2"] = np.nan
pending_df["Send From Address Line 3"] = np.nan
pending_df["Send From Suburb"] = "Inverleigh"
pending_df["Send From State"] = "VIC"
pending_df["Send From Postcode"] = "3321"
pending_df["Send From Phone Number"] = np.nan
pending_df["Send From Email Address"] = "chloehaydensmerch@gmail.com"

# Variables - delivery
pending_df["Deliver To Name"] = pending_df['Shipping Name']
pending_df["Deliver To MyPost Number"] = np.nan
pending_df["Deliver To Business Name"] = np.nan
pending_df["Deliver To Type Of Address"] = np.nan
def country_codes(country):
    if country == 'Australia':
        return 'AU'
    if country == 'United States':
        return 'US'
    elif country == 'United Kingdom':
        return 'GB'
    elif country == 'Canada':
        return 'CA'
    elif country == 'Germany':
        return 'DE'
    elif country == 'New Zealand':
        return 'NZ'
    elif country == 'Netherlands':
        return 'NL'
    elif country == 'France':
        return 'FR'
    elif country == 'Ireland':
        return 'IE'
    elif country == 'Norway':
        return 'NO'
    elif country == 'Austria':
        return 'AT'
    elif country == 'Denmark':
        return 'DK'
    elif country == 'Switzerland':
        return 'CH'
    elif country == 'Spain':
        return 'SP'
    elif country == 'Sweden':
        return 'SE'
    elif country == 'Italy':
        return 'IT'
    elif country == 'Belgium':
        return 'BE'
    elif country == 'Brazil':
        return 'BR'
    elif country == 'South Africa':
        return 'ZA'
    elif country == 'Russia':
        return 'RU'
    elif country == 'Finland':
        return 'FI'
    elif country == 'Czechia':
        return 'CZ'
    elif country == 'Israel':
        return 'IL'
    elif country == 'Mexico':
        return 'MX'
    elif country == 'Japan':
        return 'JP'
    elif country == 'Poland':
        return 'PO'
    elif country == 'Pakistan':
        return 'PK'
    elif country == 'Chile':
        return 'CL'
    elif country == 'Singapore':
        return 'SG'
    elif country == 'Republic of Korea':
        return 'KR'
    elif country == 'Phillipines':
        return 'PH'
    elif country == 'Thailand':
        return 'TH'
    elif country == 'Argentina':
        return 'AR'
    elif country == 'Costa Rica':
        return 'CR'
    elif country == 'Portugal':
        return 'PT'
    elif country == 'Romania':
        return 'RO'
    elif country == 'Vietnam':
        return 'VN'
    elif country == 'Greece':
        return 'GR'
    elif country == 'Hungary':
        return 'HU'
    elif country == 'United Arab Emirates':
        return 'AE'
    elif country == 'India':
        return 'IN'
    elif country == 'Qatar':
        return 'QA'
    elif country == 'Egypt':
        return 'EG'
    elif country == 'Indonesia':
        return 'ID'
    elif country == 'Malaysia':
        return 'MY'
    elif country == 'Peru':
        return 'PE'
    elif country == 'Puerto Rico':
        return 'PR'
    elif country == 'Uruguay':
        return 'UY'
    elif country == 'Estonia':
        return 'EE'
    elif country == 'Republic of Lithuania':
        return 'LT'
    elif country == 'Nicaragua':
        return 'NI'
    elif country == 'Saudi Arabia':
        return 'SA'
    elif country == 'Taiwan':
        return 'TW'
    elif country == 'Ukraine':
        return 'UA'
    elif country == 'Ecuador':
        return 'EC'
    elif country == 'Gibraltar':
        return 'GI'
    elif country == 'Hong Kong':
        return 'HK'
    elif country == 'Saint Kitts and Nevis':
        return 'KN'
    elif country == 'Kazakhstan':
        return 'KZ'
    elif country == 'luxembourg':
        return 'LU'
    elif country == 'Latvia':
        return 'LV'
    elif country == 'Trinidad and Tobago':
        return 'TT'
    elif country == 'Curaçao':
        return 'CW'
    elif country == 'Cyprus':
        return 'CY'
    elif country == 'Algeria':
        return 'DZ'
    elif country == 'Georgia':
        return 'GE'
    elif country == 'Guernsey':
        return 'GG'
    elif country == 'Croatia':
        return 'HR'
    elif country == 'Jersey':
        return 'JE'
    elif country == 'Sri Lanka':
        return 'LK'
    elif country == 'Morocco':
        return 'MA'
    elif country == 'Macao':
        return 'MO'
    elif country == 'Marinique':
        return 'MQ'
    elif country == 'Malta':
        return 'MT'
    elif country == 'New Caledonia':
        return 'NC'
    elif country == 'Palau':
        return 'PW'
    elif country == 'Tunisia':
        return 'TN'
    elif country == 'Turkey':
        return 'TR'
    elif country == 'Uganda':
        return 'UG'
    elif country == 'Zimbabwe':
        return 'ZW'
    
pending_df["Deliver To Country"] = pending_df['Shipping Country'].apply(lambda x: country_codes(x))
pending_df["Deliver To Address Line 1"] = pending_df['Shipping Address1']
pending_df["Deliver To Address Line 2"] = pending_df['Shipping Address2']
pending_df["Deliver To Address Line 3"] = np.nan
pending_df["Deliver To Suburb"] = pending_df['Shipping City'] 
pending_df["Deliver To State"] = pending_df['Shipping Province']
pending_df["Deliver To Postcode"] = pending_df['Shipping Zip']#.astype(int)

#assessing phone number
def clean_phone(x):
    x = x.replace("'", "")
    x = x.replace(" ", "")
    x = x.replace("\+61", "0")
    x = x.replace("nan", "")
    
    if x.startswith('04') == False or len(x) < 10:
        x = np.nan
    else:
        x = x
    
    return x


pending_df["Deliver To Phone Number"] = pending_df['Shipping Phone'].astype(str).apply(lambda x: clean_phone(x))
pending_df["Deliver To Email Address"] = pending_df['Email']

# Variables - items
pending_df["Item Packaging Type"] = 'OWN_PACKAGING'
# Determining international or domestic
def int_or_dom_service(country):
    if country == 'AU':
        return 'PP'
    else:
        return 'STD'
    
pending_df["Item Delivery Service"] = pending_df["Deliver To Country"].apply(lambda x: int_or_dom_service(x))
pending_df["Item Description"] = np.nan
pending_df["Item Length"] = pending_df['package length']
pending_df["Item Width"] = pending_df['package width']
pending_df["Item Height"] = pending_df['package height']
pending_df["Item Weight"] = pending_df['package weight'].apply(lambda x: round(x, 2)).astype(str)
pending_df["Item Dangerous Goods Flag"] = 'NO'

# Variables - other
pending_df["Signature On Delivery"] = 'NO'
pending_df["Extra Cover Amount"] = np.nan
pending_df["Cannot Be Delivered - Return To Sender / Abandon Parcel"] = 'RETURN'
pending_df["Customs Declaration - Commercial Value"] = "YES"
pending_df["Customs Declaration - Reason For Export"] = 'SALE_OF_GOODS'
pending_df["Customs Declaration - Why Are You Exporting These Goods"] = 'Delivery to Customers address'
pending_df["Export Declaration Number"] = np.nan
pending_df["SMS Tracking Notifications"] = 'NO'
pending_df["SMS Tracking Mobile Phone"] = np.nan

# %% [markdown]
# ### Domestic only

# %%
# Variables - Delivery 
pending_df["Send Tracking Notifications"] = "YES"
pending_df["Send Tracking Email"] =  "YES"
pending_df["Additional Label Information 1"] = np.nan
pending_df["Delivery Instructions"] = np.nan
pending_df["Comments"] = "Thank You! :)"
pending_df["Importer's Reference Number"] = np.nan
pending_df["Licence Numbers"] = np.nan
pending_df["Certificate Numbers"] = np.nan
pending_df["Invoice Numbers"] = np.nan


domestic_df = pending_df[pending_df["Shipping Country"] == 'Australia'].copy()
domestic = domestic_df[['Additional Label Information 1','Send Tracking Notifications',"Send From Name",
                        "Send From Business Name", "Send From Address Line 1", "Send From Address Line 2",
                         "Send From Address Line 3", "Send From Suburb", "Send From State",
                         "Send From Postcode", "Send From Phone Number", "Send From Email Address", 
                         "Deliver To Name", "Deliver To MyPost Number", "Deliver To Business Name",
                         "Deliver To Type Of Address", "Deliver To Address Line 1", "Deliver To Address Line 2",
                         "Deliver To Address Line 3", "Deliver To Suburb", "Deliver To State",
                         "Deliver To Postcode", "Deliver To Phone Number", "Deliver To Email Address",
                         "Item Packaging Type", "Item Delivery Service", "Item Description",
                         "Item Length","Item Width", "Item Height", "Item Weight", "Item Dangerous Goods Flag",
                         "Signature On Delivery", "Extra Cover Amount"]].copy()
# Fixing numbers
domestic['Deliver To Phone Number'] = domestic['Deliver To Phone Number'].astype(str)
domestic['Deliver To Phone Number'] = domestic['Deliver To Phone Number'].fillna('')
domestic['Deliver To Phone Number'] = domestic['Deliver To Phone Number'].str.replace("'", "")
domestic['Deliver To Phone Number'] = domestic['Deliver To Phone Number'].str.replace(" ", "")
domestic['Deliver To Phone Number'] = domestic['Deliver To Phone Number'].str.replace("\+61", "0", regex = True)
domestic['Deliver To Phone Number'] = domestic['Deliver To Phone Number'].str.replace("nan", "")

domestic.to_csv('upload_this_domestic_only.csv', index = False)

# %%
# Appending individual items
def items_to_go(pending_df, inventory, list_column):
    # Iterate through each row in pending_df
    for idx, row in pending_df.iterrows():
        # Extract the list of items for the current row
        item_list = row[list_column]
        package_index = 0
        
        # Iterate through each item in the list
        for item_name in item_list:
            # Skip 'Lottie and Jigglypuff'
            if item_name == 'Lottie and Jigglypuff':
                continue
            else:
             # Find item information in inventory list
                item_info = next((item for item in inventory if item.name == item_name), None)
                package_index += 1
            # If item information is found
                if item_info:
                # Increment package index
                    if package_index == 1:
                        
                        pending_df.at[idx, f"Parcel Contents - Description"] = item_info.description
                        pending_df.at[idx, f"Parcel Contents - Weight"] = item_info.weight
                        pending_df.at[idx, f"Parcel Contents - Value"] = item_info.value
                        pending_df.at[idx, f"Parcel Contents - Quantity"] = "1"
                        pending_df.at[idx, f"Parcel Contents - Country Of Origin"] = "AU"
                        pending_df.at[idx, f"Parcel Contents - HS Tariff"] = item_info.hs_tariff
                # Fill package contents columns with item information
                    else:
                        pending_df.at[idx, f"Parcel {package_index} Contents - Description"] = item_info.description
                        pending_df.at[idx, f"Parcel {package_index} Contents - Weight"] = item_info.weight
                        pending_df.at[idx, f"Parcel {package_index} Contents - Value"] = item_info.value
                        pending_df.at[idx, f"Parcel {package_index} Contents - Quantity"] = '1'
                        pending_df.at[idx, f"Parcel {package_index} Contents - Country Of Origin"] = "AU"
                        pending_df.at[idx, f"Parcel {package_index} Contents - HS Tariff"] = item_info.hs_tariff
    return pending_df

items_to_go(pending_df, inventory, 'all contents')
# Out:
#    Order ID                              Email Financial Status  \
# 0      2037             kathselkirk@icloud.com             PAID
# 1      2036  georgia.whitehead2000@hotmail.com             PAID
#
#                      Paid at Fulfillment Status  Fulfilled at Currency  \
# 0  2024-06-26 21:05:23 +1000            pending           NaN      AUD
# 1  2024-06-26 00:18:08 +1000            pending           NaN      AUD
#
#    Subtotal  Shipping  Taxes  Amount Refunded  Total  Discount Code  \
# 0      75.0      15.0    7.5              0.0   97.5            NaN
# 1      35.0      12.0    3.5              0.0   50.5            NaN
#
#    Discount Amount     Shipping Method                 Created at  \
# 0              0.0  Domestic Australia  2024-06-26 21:05:23 +1000
# 1              0.0  Domestic Australia  2024-06-26 00:18:08 +1000
#
#    Lineitem quantity                Lineitem name  Lineitem price  \
# 0                  1  Evangeline & Anura Crewneck            75.0
# 1                  1    Different not Less Beanie            35.0
#
#   Lineitem sku Lineitem variant  Lineitem requires shipping  Lineitem taxable  \
# 0    SQ1404628               XL                        True              True
# 1    SQ6900419          rainbow                        True              True
#
#   Lineitem fulfillment status       Billing Name      Billing Address1  \
# 0                     pending  Katherine Selkirk       11 Fairlawn Ave
# 1                     pending  Georgia Whitehead  66 Leighlands Avenue
#
#    Billing Address2 Billing City  Billing Zip Billing Province  \
# 0               NaN   Turramurra         2074              NSW
# 1               NaN   Ulverstone         7315              TAS
#
#   Billing Country  Billing Phone      Shipping Name     Shipping Address1  \
# 0       Australia            NaN  Katherine Selkirk       11 Fairlawn Ave
# 1       Australia    438093997.0  Georgia Whitehead  66 Leighlands Avenue
#
#    Shipping Address2 Shipping City  Shipping Zip Shipping Province  \
# 0                NaN    Turramurra          2074               NSW
# 1                NaN    Ulverstone          7315               TAS
#
#   Shipping Country  Shipping Phone  Cancelled at  Private Notes Channel Type  \
# 0        Australia             NaN           NaN            NaN       ONLINE
# 1        Australia     438093997.0           NaN            NaN       ONLINE
#
#   Channel Name  Channel Order Number  AU Tax Payment Method  \
# 0  Squarespace                  2037     7.5         Stripe
# 1  Squarespace                  2036     3.5         Stripe
#
#              Payment Reference                   all contents  package length  \
# 0  ch_3PVtfDIKuO5qFfqT0Wce1zz8  [Evangeline & Anura Crewneck]            26.5
# 1  py_3PVaBLIKuO5qFfqT0rBy7m9c    [Different not Less Beanie]            15.0
#
#    package width  package height  package weight package description  \
# 0           30.0             5.0            0.66            [Jumper]
# 1           15.0             4.0            0.12            [Beanie]
#
#          Send From Name Send From Business Name Send From Address Line 1  \
# 0  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 1  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
#
#    Send From Address Line 2  Send From Address Line 3 Send From Suburb  \
# 0                       NaN                       NaN       Inverleigh
# 1                       NaN                       NaN       Inverleigh
#
#   Send From State Send From Postcode  Send From Phone Number  \
# 0             VIC               3321                     NaN
# 1             VIC               3321                     NaN
#
#        Send From Email Address    Deliver To Name  Deliver To MyPost Number  \
# 0  chloehaydensmerch@gmail.com  Katherine Selkirk                       NaN
# 1  chloehaydensmerch@gmail.com  Georgia Whitehead                       NaN
#
#    Deliver To Business Name  Deliver To Type Of Address Deliver To Country  \
# 0                       NaN                         NaN                 AU
# 1                       NaN                         NaN                 AU
#
#   Deliver To Address Line 1  Deliver To Address Line 2  \
# 0           11 Fairlawn Ave                        NaN
# 1      66 Leighlands Avenue                        NaN
#
#    Deliver To Address Line 3 Deliver To Suburb Deliver To State  \
# 0                        NaN        Turramurra              NSW
# 1                        NaN        Ulverstone              TAS
#
#    Deliver To Postcode  Deliver To Phone Number  \
# 0                 2074                      NaN
# 1                 7315                      NaN
#
#             Deliver To Email Address Item Packaging Type  \
# 0             kathselkirk@icloud.com       OWN_PACKAGING
# 1  georgia.whitehead2000@hotmail.com       OWN_PACKAGING
#
#   Item Delivery Service  Item Description  Item Length  Item Width  \
# 0                    PP               NaN         26.5        30.0
# 1                    PP               NaN         15.0        15.0
#
#    Item Height Item Weight Item Dangerous Goods Flag Signature On Delivery  \
# 0          5.0        0.66                        NO                    NO
# 1          4.0        0.12                        NO                    NO
#
#    Extra Cover Amount Cannot Be Delivered - Return To Sender / Abandon Parcel  \
# 0                 NaN                                             RETURN
# 1                 NaN                                             RETURN
#
#   Customs Declaration - Commercial Value  \
# 0                                    YES
# 1                                    YES
#
#   Customs Declaration - Reason For Export  \
# 0                           SALE_OF_GOODS
# 1                           SALE_OF_GOODS
#
#   Customs Declaration - Why Are You Exporting These Goods  \
# 0                      Delivery to Customers address
# 1                      Delivery to Customers address
#
#    Export Declaration Number SMS Tracking Notifications  \
# 0                        NaN                         NO
# 1                        NaN                         NO
#
#    SMS Tracking Mobile Phone Send Tracking Notifications Send Tracking Email  \
# 0                        NaN                         YES                 YES
# 1                        NaN                         YES                 YES
#
#    Additional Label Information 1  Delivery Instructions       Comments  \
# 0                             NaN                    NaN  Thank You! :)
# 1                             NaN                    NaN  Thank You! :)
#
#    Importer's Reference Number  Licence Numbers  Certificate Numbers  \
# 0                          NaN              NaN                  NaN
# 1                          NaN              NaN                  NaN
#
#    Invoice Numbers Parcel Contents - Description Parcel Contents - Weight  \
# 0              NaN                        Jumper                     0.65
# 1              NaN                        Beanie                     0.11
#
#   Parcel Contents - Value Parcel Contents - Quantity  \
# 0                      75                          1
# 1                      35                          1
#
#   Parcel Contents - Country Of Origin Parcel Contents - HS Tariff
# 0                                  AU                      611011
# 1                                  AU                      650500

# %%
## Appending final columns

# Variables - Delivery 
pending_df["Send Tracking Notifications"] = "NO"
pending_df["Send Tracking Email"] =  "NO"
pending_df["Additional Label Information 1"] = np.nan
pending_df["Delivery Instructions"] = np.nan
pending_df["Comments"] = "Thank You! :)"
pending_df["Importer's Reference Number"] = np.nan
pending_df["Licence Numbers"] = np.nan
pending_df["Certificate Numbers"] = np.nan
pending_df["Invoice Numbers"] = np.nan

# %%
### Cleaning
pending_df["Deliver To Postcode"] = pending_df["Deliver To Postcode"]#.astype(int)
pending_df
# Out:
#    Order ID                              Email Financial Status  \
# 0      2037             kathselkirk@icloud.com             PAID
# 1      2036  georgia.whitehead2000@hotmail.com             PAID
#
#                      Paid at Fulfillment Status  Fulfilled at Currency  \
# 0  2024-06-26 21:05:23 +1000            pending           NaN      AUD
# 1  2024-06-26 00:18:08 +1000            pending           NaN      AUD
#
#    Subtotal  Shipping  Taxes  Amount Refunded  Total  Discount Code  \
# 0      75.0      15.0    7.5              0.0   97.5            NaN
# 1      35.0      12.0    3.5              0.0   50.5            NaN
#
#    Discount Amount     Shipping Method                 Created at  \
# 0              0.0  Domestic Australia  2024-06-26 21:05:23 +1000
# 1              0.0  Domestic Australia  2024-06-26 00:18:08 +1000
#
#    Lineitem quantity                Lineitem name  Lineitem price  \
# 0                  1  Evangeline & Anura Crewneck            75.0
# 1                  1    Different not Less Beanie            35.0
#
#   Lineitem sku Lineitem variant  Lineitem requires shipping  Lineitem taxable  \
# 0    SQ1404628               XL                        True              True
# 1    SQ6900419          rainbow                        True              True
#
#   Lineitem fulfillment status       Billing Name      Billing Address1  \
# 0                     pending  Katherine Selkirk       11 Fairlawn Ave
# 1                     pending  Georgia Whitehead  66 Leighlands Avenue
#
#    Billing Address2 Billing City  Billing Zip Billing Province  \
# 0               NaN   Turramurra         2074              NSW
# 1               NaN   Ulverstone         7315              TAS
#
#   Billing Country  Billing Phone      Shipping Name     Shipping Address1  \
# 0       Australia            NaN  Katherine Selkirk       11 Fairlawn Ave
# 1       Australia    438093997.0  Georgia Whitehead  66 Leighlands Avenue
#
#    Shipping Address2 Shipping City  Shipping Zip Shipping Province  \
# 0                NaN    Turramurra          2074               NSW
# 1                NaN    Ulverstone          7315               TAS
#
#   Shipping Country  Shipping Phone  Cancelled at  Private Notes Channel Type  \
# 0        Australia             NaN           NaN            NaN       ONLINE
# 1        Australia     438093997.0           NaN            NaN       ONLINE
#
#   Channel Name  Channel Order Number  AU Tax Payment Method  \
# 0  Squarespace                  2037     7.5         Stripe
# 1  Squarespace                  2036     3.5         Stripe
#
#              Payment Reference                   all contents  package length  \
# 0  ch_3PVtfDIKuO5qFfqT0Wce1zz8  [Evangeline & Anura Crewneck]            26.5
# 1  py_3PVaBLIKuO5qFfqT0rBy7m9c    [Different not Less Beanie]            15.0
#
#    package width  package height  package weight package description  \
# 0           30.0             5.0            0.66            [Jumper]
# 1           15.0             4.0            0.12            [Beanie]
#
#          Send From Name Send From Business Name Send From Address Line 1  \
# 0  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 1  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
#
#    Send From Address Line 2  Send From Address Line 3 Send From Suburb  \
# 0                       NaN                       NaN       Inverleigh
# 1                       NaN                       NaN       Inverleigh
#
#   Send From State Send From Postcode  Send From Phone Number  \
# 0             VIC               3321                     NaN
# 1             VIC               3321                     NaN
#
#        Send From Email Address    Deliver To Name  Deliver To MyPost Number  \
# 0  chloehaydensmerch@gmail.com  Katherine Selkirk                       NaN
# 1  chloehaydensmerch@gmail.com  Georgia Whitehead                       NaN
#
#    Deliver To Business Name  Deliver To Type Of Address Deliver To Country  \
# 0                       NaN                         NaN                 AU
# 1                       NaN                         NaN                 AU
#
#   Deliver To Address Line 1  Deliver To Address Line 2  \
# 0           11 Fairlawn Ave                        NaN
# 1      66 Leighlands Avenue                        NaN
#
#    Deliver To Address Line 3 Deliver To Suburb Deliver To State  \
# 0                        NaN        Turramurra              NSW
# 1                        NaN        Ulverstone              TAS
#
#    Deliver To Postcode  Deliver To Phone Number  \
# 0                 2074                      NaN
# 1                 7315                      NaN
#
#             Deliver To Email Address Item Packaging Type  \
# 0             kathselkirk@icloud.com       OWN_PACKAGING
# 1  georgia.whitehead2000@hotmail.com       OWN_PACKAGING
#
#   Item Delivery Service  Item Description  Item Length  Item Width  \
# 0                    PP               NaN         26.5        30.0
# 1                    PP               NaN         15.0        15.0
#
#    Item Height Item Weight Item Dangerous Goods Flag Signature On Delivery  \
# 0          5.0        0.66                        NO                    NO
# 1          4.0        0.12                        NO                    NO
#
#    Extra Cover Amount Cannot Be Delivered - Return To Sender / Abandon Parcel  \
# 0                 NaN                                             RETURN
# 1                 NaN                                             RETURN
#
#   Customs Declaration - Commercial Value  \
# 0                                    YES
# 1                                    YES
#
#   Customs Declaration - Reason For Export  \
# 0                           SALE_OF_GOODS
# 1                           SALE_OF_GOODS
#
#   Customs Declaration - Why Are You Exporting These Goods  \
# 0                      Delivery to Customers address
# 1                      Delivery to Customers address
#
#    Export Declaration Number SMS Tracking Notifications  \
# 0                        NaN                         NO
# 1                        NaN                         NO
#
#    SMS Tracking Mobile Phone Send Tracking Notifications Send Tracking Email  \
# 0                        NaN                          NO                  NO
# 1                        NaN                          NO                  NO
#
#    Additional Label Information 1  Delivery Instructions       Comments  \
# 0                             NaN                    NaN  Thank You! :)
# 1                             NaN                    NaN  Thank You! :)
#
#    Importer's Reference Number  Licence Numbers  Certificate Numbers  \
# 0                          NaN              NaN                  NaN
# 1                          NaN              NaN                  NaN
#
#    Invoice Numbers Parcel Contents - Description Parcel Contents - Weight  \
# 0              NaN                        Jumper                     0.65
# 1              NaN                        Beanie                     0.11
#
#   Parcel Contents - Value Parcel Contents - Quantity  \
# 0                      75                          1
# 1                      35                          1
#
#   Parcel Contents - Country Of Origin Parcel Contents - HS Tariff
# 0                                  AU                      611011
# 1                                  AU                      650500

# %% [raw]
# # If the template changes, use this
#
# columns = template_df.columns.to_list()
#
# for x in columns:
#     print(f"""orders_df["{x}"]""")

# %%
pending_df.to_csv('upload_this.csv')

# %% [markdown]
# ### Importing with API

# %%
import requests
import json
from datetime import datetime, timezone

# %%
# Getting time
current_time_utc = datetime.now(timezone.utc)
formatted_time = current_time_utc.strftime('%Y-%m-%dT%H:%M:%SZ')

# Using API to retrieve pending orders
url = f"https://api.squarespace.com/1.0/commerce/orders?modifiedBefore={formatted_time}&modifiedAfter=2023-01-01T01:00:00Z&fulfillmentStatus={'PENDING'}"
headers = {
    "Authorization": "Bearer 4d00ecf2-edd8-4cf4-a4e0-cff6c7917691",
    "User-Agent": "me..",
    "Content-Type": "application/json"
}

response = requests.get(url, headers = headers)

# Confirming 
if response.status_code == 200:
    print('Success')
elif response.status_code == 204:
    print('No content')
else:
    print('Error')
# Out:
# Success

# %% [markdown]
# ### Explanation of JSON
# In the data frame, each row represents a differnt order. In the 'lineItem' column, the values act as nested dictionaries for items in the order.
# Each dictionary contains:
# - id
# - variantId
# - sku
# - weight
# - width
# - length
# - height
# - productId
# - productName------> Relevant
# - quantity   ------> Relevant
# - unitPricePaid ---> Relevant
# - variantOptions
# - customization
# - imageUrl
# - lineItemType ----> Relevant

# %%
# Compiling as dataframe
pending_df = pd.json_normalize(response.json(), 'result')

# %%
# Taking relevant information
relevant_df = pending_df[['orderNumber','createdOn', 'customerEmail', 'shippingAddress.firstName', 
                          'shippingAddress.lastName', 'shippingAddress.address1', 'shippingAddress.address2', 
                          'shippingAddress.city', 'shippingAddress.state', 'shippingAddress.countryCode', 
                          'shippingAddress.postalCode', 'shippingAddress.phone', 'lineItems','subtotal.value', 
                          ]].copy()

# %%
## Assessing phone number
def clean_phone(x):
    x = x.replace("'", "")
    x = x.replace(" ", "")
    x = x.replace("\+61", "0")
    x = x.replace("nan", "")
    
    if x.startswith('04') == False or len(x) < 10:
        x = np.nan
    else:
        x = x
    
    return x

# %%
## Assessing delivery type based on country
def int_or_dom_service(country):
    if country == 'AU':
        return 'PP'
    else:
        return 'STD'

# %%
# Initialize a dictionary to store item classes
class Item:
    def __init__(self, name, length, width, height, weight, material, description, hs_tarrif, value):
        self.name = name
        self.length = length
        self.width = width
        self.height = height
        self.weight = weight
        self.material = material
        self.description = description
        self.hs_tariff = hs_tarrif
        self.value = value
        
    
inventory = []
# Replace 'your_file.csv' with the path to your CSV file
with open('inventory_properties.csv', 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    # Skip the header row if it exists
    next(csv_reader, None)

    for row in csv_reader:
        # Item	Length	Width	Height	Weight	Material	Description	Hs tarrif value
        item = Item(str(row[0]), str(row[1]), str(row[2]), str(row[3]), str(row[4]), 
                    str(row[5]), str(row[6]), str(row[7]), str(row[8]))
        inventory.append(item)
        
# Gathering package properties 
def package_properties(package_contents):
        length = 0
        width = 0
        height = 0
        weight = 0
        description = []
        
        for element in package_contents:
            for item in inventory:
                if item.name == element:                 # If the item in the order matches the name in the inventory list
                    height += float(item.height)           # Sum it's height
                    weight += float(item.weight)            # ... it's weight
                
                    if length < float(item.length):        # take the largest length
                        length = float(item.length)        
                    if width < float(item.width):          # and the widest width
                        width = float(item.width)           
                    description.append(str(item.description)) # and adds the item to the package description
        
        return length, width, height, weight, description

# %%
# Extending dataframe to explicitly write the shipping address

# Shipping variables
relevant_df.rename(columns={'shippingAddress.address1': 'Deliver To Address Line 1',
                            'shippingAddress.address2': 'Deliver To Address Line 2',
                            'shippingAddress.city': 'Deliver To Suburb',
                            'shippingAddress.state': 'Deliver To State',
                            'shippingAddress.postalCode': 'Deliver To Postcode',
                            'shippingAddress.phone': 'Deliver To Phone Number',
                            'shippingAddress.countryCode': 'Deliver To Country',
                            'customerEmail' : 'Deliver To Email Address'
                           }, inplace=True)
relevant_df["Deliver To Address Line 3"] = np.nan
relevant_df["Deliver To Phone Number"] = relevant_df['Deliver To Phone Number'].astype(str).apply(lambda x: clean_phone(x))
relevant_df['Deliver To Name'] = relevant_df['shippingAddress.firstName'] + " " + relevant_df['shippingAddress.lastName']

# Seller variables
relevant_df["Send From Name"] = "Chloe Hayden ltd pty"
relevant_df["Send From Business Name"] = "Chloe Hayden"
relevant_df["Send From Address Line 1"] = "PO BOX 137"
relevant_df["Send From Address Line 2"] = np.nan
relevant_df["Send From Address Line 3"] = np.nan
relevant_df["Send From Suburb"] = "Inverleigh"
relevant_df["Send From State"] = "VIC"
relevant_df["Send From Postcode"] = "3321"
relevant_df["Send From Phone Number"] = np.nan
relevant_df["Send From Email Address"] = "chloehaydensmerch@gmail.com"



# Label variables
relevant_df["Send Tracking Notifications"] = "NO"
relevant_df["Send Tracking Email"] =  "NO"
relevant_df["Additional Label Information 1"] = np.nan
relevant_df["Delivery Instructions"] = np.nan
relevant_df["Comments"] = "Thank You! :)"
relevant_df["Importer's Reference Number"] = np.nan
relevant_df["Licence Numbers"] = np.nan
relevant_df["Certificate Numbers"] = np.nan
relevant_df["Invoice Numbers"] = np.nan

# Package variables
relevant_df["Item Delivery Service"] = relevant_df["Deliver To Country"].apply(lambda x: int_or_dom_service(x))
relevant_df["Item Packaging Type"] = 'OWN_PACKAGING'
relevant_df["Item Dangerous Goods Flag"] = 'NO'

# Set variables - other
relevant_df["Signature On Delivery"] = 'NO'
relevant_df["Extra Cover Amount"] = np.nan
relevant_df["Cannot Be Delivered - Return To Sender / Abandon Parcel"] = 'RETURN'
relevant_df["Customs Declaration - Commercial Value"] = "YES"
relevant_df["Customs Declaration - Reason For Export"] = 'SALE_OF_GOODS'
relevant_df["Customs Declaration - Why Are You Exporting These Goods"] = 'Delivery to Customers address'
relevant_df["Export Declaration Number"] = np.nan
relevant_df["SMS Tracking Notifications"] = 'NO'
relevant_df["SMS Tracking Mobile Phone"] = np.nan
relevant_df["Deliver To MyPost Number"] = np.nan
relevant_df["Deliver To Business Name"] = np.nan
relevant_df["Deliver To Type Of Address"] = np.nan

relevant_df
# Out:
#    orderNumber                 createdOn          Deliver To Email Address  \
# 0         2038  2024-06-27T03:26:54.519Z          isabellamilne@y7mail.com
# 1         2034  2024-06-24T23:17:45.374Z              lindap82@hotmail.com
# 2         2029  2024-06-20T04:02:40.909Z              fi_scott@hotmail.com
# 3         2027  2024-06-19T15:04:31.148Z        molly.roberts1@hotmail.com
# 4         2021  2024-06-16T04:52:51.103Z          dramaqueenbh23@gmail.com
# 5         1998  2024-06-10T10:31:09.362Z             n.mcgrady@hotmail.com
# 6         1997  2024-06-10T09:24:44.171Z      sarah.li.jenkinson@gmail.com
# 7         1996  2024-06-10T08:13:24.073Z           kat.tsangaris@gmail.com
# 8         1995  2024-06-10T08:11:01.830Z              valooo1998@gmail.com
# 9         1991  2024-06-07T12:42:28.125Z  steph.graves61@schools.sa.edu.au
# 10        1986  2024-06-05T16:20:55.522Z              katzekarla@ymail.com
# 11        1984  2024-06-05T09:54:15.215Z             emmakathome@gmail.com
# 12        1983  2024-06-04T13:33:08.054Z         josefgarrington@gmail.com
# 13        1980  2024-06-04T04:20:15.670Z      hayleyhawrylciw@yahoo.com.au
# 14        1978  2024-06-03T23:13:06.095Z       mikaylamartin2498@gmail.com
# 15        1977  2024-06-03T21:35:24.420Z       charlie.jenkins@zohomail.eu
# 16        1976  2024-06-03T21:27:07.444Z           amelie.rose99@gmail.com
# 17        1973  2024-06-03T11:38:02.683Z           isabelfooskas@gmail.com
# 18        1972  2024-06-03T11:34:53.737Z               amber@salted.com.au
# 19        1971  2024-06-03T11:22:13.034Z     maryashleysamuelson@gmail.com
# 20        1970  2024-06-03T11:17:36.636Z              sashtag135@gmail.com
#
#    shippingAddress.firstName shippingAddress.lastName  \
# 0                   Isabella                    Milne
# 1                      Linda                  Jenkins
# 2                      Fiona                    Keele
# 3                      Molly                  Roberts
# 4                    Brookie                  Hamence
# 5                     Nicole                  McGrady
# 6                      Sarah                Jenkinson
# 7                     Katina                    Ayoub
# 8                       Drew                   Nugent
# 9                      Steph                     Dent
# 10                      Jana                     Dutz
# 11                      Emma                   Knight
# 12                     Josef               Garrington
# 13                    Hayley                Hawrylciw
# 14                   Mikayla                   Martin
# 15                   Charlie                  Jenkins
# 16                    Amelie            Blondin-Bayly
# 17                    Isabel                  Fooskas
# 18                     Amber                   Morris
# 19                      Mary                Samuelson
# 20                     Sasha                   Ferris
#
#    Deliver To Address Line 1 Deliver To Address Line 2 Deliver To Suburb  \
# 0            17 Coral Avenue                      None         Footscray
# 1          5 Belvedere Court                      None  Moore Park Beach
# 2          23 McSwain Street                      None          Parkdale
# 3           10 Readshaw Road                      None          Duncraig
# 4       U 7/370a Eleventh St                      None           Mildura
# 5            23 Grove Street                 Balderton            Newark
# 6              10 Auburn Pde                      None     Hawthorn East
# 7            28 Perry Street                      None        Matraville
# 8            24 Cambridge St                 Cambridge           ROZELLE
# 9                PO Box 1234         Peramangk Country            Nairne
# 10           20 Pilotystraße                      None          Nürnberg
# 11             5 Musgrave St                      None          Goodwood
# 12          19-23 Stewart St                        13             Glebe
# 13           38 Cannery Road                      None          Plumpton
# 14         10 Bastow Circuit                      None             Banks
# 15       8 Cromwell Crescent                      None        Pontefract
# 16                        53              Cuzco Strest      South Coogee
# 17         205 Woodward Road                      None             Media
# 18          56 Middle Street            McMahons Point            Sydney
# 19            480 Commons Dr                  Apt 2112          Burleson
# 20       135 Bellevue Street                      None          CAMMERAY
#
#    Deliver To State Deliver To Country Deliver To Postcode  \
# 0               VIC                 AU                3011
# 1               QLD                 AU                4670
# 2              None                 AU                3195
# 3                WA                 AU                6023
# 4               VIC                 AU                3500
# 5   Nottinghamshire                 GB            NG24 3AR
# 6               VIC                 AU                3123
# 7               NSW                 AU                2036
# 8               NSW                 AU                2039
# 9                SA                 AU                5252
# 10               BY                 DE               90408
# 11               SA                 AU                5034
# 12              NSW                 AU                2037
# 13              NSW                 AU                2761
# 14              ACT                 AU                2906
# 15          England                 GB             WF8 2EG
# 16              NSW                 AU                2034
# 17               PA                 US               19063
# 18              NSW                 AU                2060
# 19               TX                 US               76028
# 20              NSW                 AU                2062
#
#    Deliver To Phone Number                                          lineItems  \
# 0               0412224395  [{'id': '667cdb2682a764450ede4a31', 'variantId...
# 1               0416173325  [{'id': '6674fbb38e3d142939ad95b4', 'variantId...
# 2               0407978711  [{'id': '666f6033cf6ce4549b437ce3', 'variantId...
# 3               0423478487  [{'id': '6672ef88cf6ce4549b48216a', 'variantId...
# 4               0429211333  [{'id': '666e6e43cf6ce4549b425718', 'variantId...
# 5                      NaN  [{'id': '665dab3662d202185c37dfc1', 'variantId...
# 6                      NaN  [{'id': '6666c6136c2ded7ceecfb666', 'variantId...
# 7               0422885811  [{'id': '6666b4bbe898525815cf2749', 'variantId...
# 8               0423941905  [{'id': '6666b27d6c2ded7ceecfa4b5', 'variantId...
# 9               0421958471  [{'id': '6662ff8fe898525815c9a446', 'variantId...
# 10                     NaN  [{'id': '66608f357493191e5a5ec094', 'variantId...
# 11                     NaN  [{'id': '6660351d8d645631f9ef6b67', 'variantId...
# 12                     NaN  [{'id': '665f167e8d645631f9edb9f4', 'variantId...
# 13              0417620589  [{'id': '665e952d8d645631f9ed3a16', 'variantId...
# 14              0424604518  [{'id': '665e4ce4e708a5173b4ad3d2', 'variantId...
# 15                     NaN  [{'id': '665e368c7493191e5a5b6e58', 'variantId...
# 16                     NaN  [{'id': '665e3507e708a5173b4aa0a8', 'variantId...
# 17                     NaN  [{'id': '665daa1f62d202185c37de81', 'variantId...
# 18                     NaN  [{'id': '665da9de03164b09dc984699', 'variantId...
# 19                     NaN  [{'id': '665da6d103164b09dc984348', 'variantId...
# 20              0457686266  [{'id': '665da5b484d00d270e91fe24', 'variantId...
#
#    subtotal.value  Deliver To Address Line 3       Deliver To Name  \
# 0           15.00                        NaN        Isabella Milne
# 1           65.00                        NaN         Linda Jenkins
# 2           20.00                        NaN           Fiona Keele
# 3           20.00                        NaN         Molly Roberts
# 4           35.00                        NaN       Brookie Hamence
# 5           65.00                        NaN        Nicole McGrady
# 6           20.00                        NaN       Sarah Jenkinson
# 7           65.00                        NaN          Katina Ayoub
# 8           40.00                        NaN           Drew Nugent
# 9           20.00                        NaN            Steph Dent
# 10          55.00                        NaN             Jana Dutz
# 11          80.00                        NaN           Emma Knight
# 12          65.00                        NaN      Josef Garrington
# 13         140.00                        NaN      Hayley Hawrylciw
# 14          20.00                        NaN        Mikayla Martin
# 15          65.00                        NaN       Charlie Jenkins
# 16          20.00                        NaN  Amelie Blondin-Bayly
# 17          65.00                        NaN        Isabel Fooskas
# 18          55.00                        NaN          Amber Morris
# 19          20.00                        NaN        Mary Samuelson
# 20          20.00                        NaN          Sasha Ferris
#
#           Send From Name Send From Business Name Send From Address Line 1  \
# 0   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 1   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 2   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 3   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 4   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 5   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 6   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 7   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 8   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 9   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 10  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 11  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 12  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 13  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 14  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 15  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 16  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 17  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 18  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 19  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 20  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
#
#     Send From Address Line 2  Send From Address Line 3 Send From Suburb  \
# 0                        NaN                       NaN       Inverleigh
# 1                        NaN                       NaN       Inverleigh
# 2                        NaN                       NaN       Inverleigh
# 3                        NaN                       NaN       Inverleigh
# 4                        NaN                       NaN       Inverleigh
# 5                        NaN                       NaN       Inverleigh
# 6                        NaN                       NaN       Inverleigh
# 7                        NaN                       NaN       Inverleigh
# 8                        NaN                       NaN       Inverleigh
# 9                        NaN                       NaN       Inverleigh
# 10                       NaN                       NaN       Inverleigh
# 11                       NaN                       NaN       Inverleigh
# 12                       NaN                       NaN       Inverleigh
# 13                       NaN                       NaN       Inverleigh
# 14                       NaN                       NaN       Inverleigh
# 15                       NaN                       NaN       Inverleigh
# 16                       NaN                       NaN       Inverleigh
# 17                       NaN                       NaN       Inverleigh
# 18                       NaN                       NaN       Inverleigh
# 19                       NaN                       NaN       Inverleigh
# 20                       NaN                       NaN       Inverleigh
#
#    Send From State Send From Postcode  Send From Phone Number  \
# 0              VIC               3321                     NaN
# 1              VIC               3321                     NaN
# 2              VIC               3321                     NaN
# 3              VIC               3321                     NaN
# 4              VIC               3321                     NaN
# 5              VIC               3321                     NaN
# 6              VIC               3321                     NaN
# 7              VIC               3321                     NaN
# 8              VIC               3321                     NaN
# 9              VIC               3321                     NaN
# 10             VIC               3321                     NaN
# 11             VIC               3321                     NaN
# 12             VIC               3321                     NaN
# 13             VIC               3321                     NaN
# 14             VIC               3321                     NaN
# 15             VIC               3321                     NaN
# 16             VIC               3321                     NaN
# 17             VIC               3321                     NaN
# 18             VIC               3321                     NaN
# 19             VIC               3321                     NaN
# 20             VIC               3321                     NaN
#
#         Send From Email Address Send Tracking Notifications  \
# 0   chloehaydensmerch@gmail.com                          NO
# 1   chloehaydensmerch@gmail.com                          NO
# 2   chloehaydensmerch@gmail.com                          NO
# 3   chloehaydensmerch@gmail.com                          NO
# 4   chloehaydensmerch@gmail.com                          NO
# 5   chloehaydensmerch@gmail.com                          NO
# 6   chloehaydensmerch@gmail.com                          NO
# 7   chloehaydensmerch@gmail.com                          NO
# 8   chloehaydensmerch@gmail.com                          NO
# 9   chloehaydensmerch@gmail.com                          NO
# 10  chloehaydensmerch@gmail.com                          NO
# 11  chloehaydensmerch@gmail.com                          NO
# 12  chloehaydensmerch@gmail.com                          NO
# 13  chloehaydensmerch@gmail.com                          NO
# 14  chloehaydensmerch@gmail.com                          NO
# 15  chloehaydensmerch@gmail.com                          NO
# 16  chloehaydensmerch@gmail.com                          NO
# 17  chloehaydensmerch@gmail.com                          NO
# 18  chloehaydensmerch@gmail.com                          NO
# 19  chloehaydensmerch@gmail.com                          NO
# 20  chloehaydensmerch@gmail.com                          NO
#
#    Send Tracking Email  Additional Label Information 1  Delivery Instructions  \
# 0                   NO                             NaN                    NaN
# 1                   NO                             NaN                    NaN
# 2                   NO                             NaN                    NaN
# 3                   NO                             NaN                    NaN
# 4                   NO                             NaN                    NaN
# 5                   NO                             NaN                    NaN
# 6                   NO                             NaN                    NaN
# 7                   NO                             NaN                    NaN
# 8                   NO                             NaN                    NaN
# 9                   NO                             NaN                    NaN
# 10                  NO                             NaN                    NaN
# 11                  NO                             NaN                    NaN
# 12                  NO                             NaN                    NaN
# 13                  NO                             NaN                    NaN
# 14                  NO                             NaN                    NaN
# 15                  NO                             NaN                    NaN
# 16                  NO                             NaN                    NaN
# 17                  NO                             NaN                    NaN
# 18                  NO                             NaN                    NaN
# 19                  NO                             NaN                    NaN
# 20                  NO                             NaN                    NaN
#
#          Comments  Importer's Reference Number  Licence Numbers  \
# 0   Thank You! :)                          NaN              NaN
# 1   Thank You! :)                          NaN              NaN
# 2   Thank You! :)                          NaN              NaN
# 3   Thank You! :)                          NaN              NaN
# 4   Thank You! :)                          NaN              NaN
# 5   Thank You! :)                          NaN              NaN
# 6   Thank You! :)                          NaN              NaN
# 7   Thank You! :)                          NaN              NaN
# 8   Thank You! :)                          NaN              NaN
# 9   Thank You! :)                          NaN              NaN
# 10  Thank You! :)                          NaN              NaN
# 11  Thank You! :)                          NaN              NaN
# 12  Thank You! :)                          NaN              NaN
# 13  Thank You! :)                          NaN              NaN
# 14  Thank You! :)                          NaN              NaN
# 15  Thank You! :)                          NaN              NaN
# 16  Thank You! :)                          NaN              NaN
# 17  Thank You! :)                          NaN              NaN
# 18  Thank You! :)                          NaN              NaN
# 19  Thank You! :)                          NaN              NaN
# 20  Thank You! :)                          NaN              NaN
#
#     Certificate Numbers  Invoice Numbers Item Delivery Service  \
# 0                   NaN              NaN                    PP
# 1                   NaN              NaN                    PP
# 2                   NaN              NaN                    PP
# 3                   NaN              NaN                    PP
# 4                   NaN              NaN                    PP
# 5                   NaN              NaN                   STD
# 6                   NaN              NaN                    PP
# 7                   NaN              NaN                    PP
# 8                   NaN              NaN                    PP
# 9                   NaN              NaN                    PP
# 10                  NaN              NaN                   STD
# 11                  NaN              NaN                    PP
# 12                  NaN              NaN                    PP
# 13                  NaN              NaN                    PP
# 14                  NaN              NaN                    PP
# 15                  NaN              NaN                   STD
# 16                  NaN              NaN                    PP
# 17                  NaN              NaN                   STD
# 18                  NaN              NaN                    PP
# 19                  NaN              NaN                   STD
# 20                  NaN              NaN                    PP
#
#    Item Packaging Type Item Dangerous Goods Flag Signature On Delivery  \
# 0        OWN_PACKAGING                        NO                    NO
# 1        OWN_PACKAGING                        NO                    NO
# 2        OWN_PACKAGING                        NO                    NO
# 3        OWN_PACKAGING                        NO                    NO
# 4        OWN_PACKAGING                        NO                    NO
# 5        OWN_PACKAGING                        NO                    NO
# 6        OWN_PACKAGING                        NO                    NO
# 7        OWN_PACKAGING                        NO                    NO
# 8        OWN_PACKAGING                        NO                    NO
# 9        OWN_PACKAGING                        NO                    NO
# 10       OWN_PACKAGING                        NO                    NO
# 11       OWN_PACKAGING                        NO                    NO
# 12       OWN_PACKAGING                        NO                    NO
# 13       OWN_PACKAGING                        NO                    NO
# 14       OWN_PACKAGING                        NO                    NO
# 15       OWN_PACKAGING                        NO                    NO
# 16       OWN_PACKAGING                        NO                    NO
# 17       OWN_PACKAGING                        NO                    NO
# 18       OWN_PACKAGING                        NO                    NO
# 19       OWN_PACKAGING                        NO                    NO
# 20       OWN_PACKAGING                        NO                    NO
#
#     Extra Cover Amount  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
#
#    Cannot Be Delivered - Return To Sender / Abandon Parcel  \
# 0                                              RETURN
# 1                                              RETURN
# 2                                              RETURN
# 3                                              RETURN
# 4                                              RETURN
# 5                                              RETURN
# 6                                              RETURN
# 7                                              RETURN
# 8                                              RETURN
# 9                                              RETURN
# 10                                             RETURN
# 11                                             RETURN
# 12                                             RETURN
# 13                                             RETURN
# 14                                             RETURN
# 15                                             RETURN
# 16                                             RETURN
# 17                                             RETURN
# 18                                             RETURN
# 19                                             RETURN
# 20                                             RETURN
#
#    Customs Declaration - Commercial Value  \
# 0                                     YES
# 1                                     YES
# 2                                     YES
# 3                                     YES
# 4                                     YES
# 5                                     YES
# 6                                     YES
# 7                                     YES
# 8                                     YES
# 9                                     YES
# 10                                    YES
# 11                                    YES
# 12                                    YES
# 13                                    YES
# 14                                    YES
# 15                                    YES
# 16                                    YES
# 17                                    YES
# 18                                    YES
# 19                                    YES
# 20                                    YES
#
#    Customs Declaration - Reason For Export  \
# 0                            SALE_OF_GOODS
# 1                            SALE_OF_GOODS
# 2                            SALE_OF_GOODS
# 3                            SALE_OF_GOODS
# 4                            SALE_OF_GOODS
# 5                            SALE_OF_GOODS
# 6                            SALE_OF_GOODS
# 7                            SALE_OF_GOODS
# 8                            SALE_OF_GOODS
# 9                            SALE_OF_GOODS
# 10                           SALE_OF_GOODS
# 11                           SALE_OF_GOODS
# 12                           SALE_OF_GOODS
# 13                           SALE_OF_GOODS
# 14                           SALE_OF_GOODS
# 15                           SALE_OF_GOODS
# 16                           SALE_OF_GOODS
# 17                           SALE_OF_GOODS
# 18                           SALE_OF_GOODS
# 19                           SALE_OF_GOODS
# 20                           SALE_OF_GOODS
#
#    Customs Declaration - Why Are You Exporting These Goods  \
# 0                       Delivery to Customers address
# 1                       Delivery to Customers address
# 2                       Delivery to Customers address
# 3                       Delivery to Customers address
# 4                       Delivery to Customers address
# 5                       Delivery to Customers address
# 6                       Delivery to Customers address
# 7                       Delivery to Customers address
# 8                       Delivery to Customers address
# 9                       Delivery to Customers address
# 10                      Delivery to Customers address
# 11                      Delivery to Customers address
# 12                      Delivery to Customers address
# 13                      Delivery to Customers address
# 14                      Delivery to Customers address
# 15                      Delivery to Customers address
# 16                      Delivery to Customers address
# 17                      Delivery to Customers address
# 18                      Delivery to Customers address
# 19                      Delivery to Customers address
# 20                      Delivery to Customers address
#
#     Export Declaration Number SMS Tracking Notifications  \
# 0                         NaN                         NO
# 1                         NaN                         NO
# 2                         NaN                         NO
# 3                         NaN                         NO
# 4                         NaN                         NO
# 5                         NaN                         NO
# 6                         NaN                         NO
# 7                         NaN                         NO
# 8                         NaN                         NO
# 9                         NaN                         NO
# 10                        NaN                         NO
# 11                        NaN                         NO
# 12                        NaN                         NO
# 13                        NaN                         NO
# 14                        NaN                         NO
# 15                        NaN                         NO
# 16                        NaN                         NO
# 17                        NaN                         NO
# 18                        NaN                         NO
# 19                        NaN                         NO
# 20                        NaN                         NO
#
#     SMS Tracking Mobile Phone  Deliver To MyPost Number  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# 8                         NaN                       NaN
# 9                         NaN                       NaN
# 10                        NaN                       NaN
# 11                        NaN                       NaN
# 12                        NaN                       NaN
# 13                        NaN                       NaN
# 14                        NaN                       NaN
# 15                        NaN                       NaN
# 16                        NaN                       NaN
# 17                        NaN                       NaN
# 18                        NaN                       NaN
# 19                        NaN                       NaN
# 20                        NaN                       NaN
#
#     Deliver To Business Name  Deliver To Type Of Address
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# 5                        NaN                         NaN
# 6                        NaN                         NaN
# 7                        NaN                         NaN
# 8                        NaN                         NaN
# 9                        NaN                         NaN
# 10                       NaN                         NaN
# 11                       NaN                         NaN
# 12                       NaN                         NaN
# 13                       NaN                         NaN
# 14                       NaN                         NaN
# 15                       NaN                         NaN
# 16                       NaN                         NaN
# 17                       NaN                         NaN
# 18                       NaN                         NaN
# 19                       NaN                         NaN
# 20                       NaN                         NaN

# %%
## Obtaining cart info as a dictionary
#def cart_contents(order_id, dataframe):
#    order = relevant_df[relevant_df['orderNumber'] == order_id]
#    cart = {}
#    for element in order['lineItems']:
#        for item in range(0, len(element)):
#            cart[element[item].get('productName')] = element[item].get('quantity')
#    return cart
#        
#    # use this test code to finish next section (order summary)
#cart_contents('2021', relevant_df)

# %%
# Obtaining cart info
def cart_contents(order_id, dataframe):
    order = relevant_df[relevant_df['orderNumber'] == order_id]
    cart = []
    for element in order['lineItems']:
        for item in range(0, len(element)):
            quantity = element[item].get('quantity')
            for n in range(0, quantity):
                cart.append(element[item].get('productName'))
    return cart

# %%
# Creating column to hold new dictionary
relevant_df["cart"] = relevant_df["orderNumber"].map(lambda x: cart_contents(x, orders_df))
relevant_df.head(1)
# Out:
#   orderNumber                 createdOn  Deliver To Email Address  \
# 0        2038  2024-06-27T03:26:54.519Z  isabellamilne@y7mail.com
#
#   shippingAddress.firstName shippingAddress.lastName  \
# 0                  Isabella                    Milne
#
#   Deliver To Address Line 1 Deliver To Address Line 2 Deliver To Suburb  \
# 0           17 Coral Avenue                      None         Footscray
#
#   Deliver To State Deliver To Country Deliver To Postcode  \
# 0              VIC                 AU                3011
#
#   Deliver To Phone Number                                          lineItems  \
# 0              0412224395  [{'id': '667cdb2682a764450ede4a31', 'variantId...
#
#   subtotal.value  Deliver To Address Line 3 Deliver To Name  \
# 0          15.00                        NaN  Isabella Milne
#
#          Send From Name Send From Business Name Send From Address Line 1  \
# 0  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
#
#    Send From Address Line 2  Send From Address Line 3 Send From Suburb  \
# 0                       NaN                       NaN       Inverleigh
#
#   Send From State Send From Postcode  Send From Phone Number  \
# 0             VIC               3321                     NaN
#
#        Send From Email Address Send Tracking Notifications  \
# 0  chloehaydensmerch@gmail.com                          NO
#
#   Send Tracking Email  Additional Label Information 1  Delivery Instructions  \
# 0                  NO                             NaN                    NaN
#
#         Comments  Importer's Reference Number  Licence Numbers  \
# 0  Thank You! :)                          NaN              NaN
#
#    Certificate Numbers  Invoice Numbers Item Delivery Service  \
# 0                  NaN              NaN                    PP
#
#   Item Packaging Type Item Dangerous Goods Flag Signature On Delivery  \
# 0       OWN_PACKAGING                        NO                    NO
#
#    Extra Cover Amount Cannot Be Delivered - Return To Sender / Abandon Parcel  \
# 0                 NaN                                             RETURN
#
#   Customs Declaration - Commercial Value  \
# 0                                    YES
#
#   Customs Declaration - Reason For Export  \
# 0                           SALE_OF_GOODS
#
#   Customs Declaration - Why Are You Exporting These Goods  \
# 0                      Delivery to Customers address
#
#    Export Declaration Number SMS Tracking Notifications  \
# 0                        NaN                         NO
#
#    SMS Tracking Mobile Phone  Deliver To MyPost Number  \
# 0                        NaN                       NaN
#
#    Deliver To Business Name  Deliver To Type Of Address  \
# 0                       NaN                         NaN
#
#                                     cart
# 0  [13 Wise Women (The COVID Year) Book]

# %%
# Create new columns in the orders_df DataFrame
relevant_df['Item Length'] = relevant_df['cart'].apply(lambda x: package_properties(x)[0])
relevant_df['Item Width'] = relevant_df['cart'].apply(lambda x: package_properties(x)[1])
relevant_df['Item Height'] = relevant_df['cart'].apply(lambda x: package_properties(x)[2])
relevant_df['Item Weight'] = relevant_df['cart'].apply(lambda x: package_properties(x)[3])
relevant_df['Item Description'] = relevant_df['cart'].apply(lambda x: f"You are expecting {len(x)} item/s")

# %%
# Looking for largest order
max_items = 0
for x in relevant_df['lineItems']:
    if len(x) > max_items:
        max_items = len(x)

# Appending individual items
def defining_package(dataframe, inventory, dict_column):
    # Iterate through each row in dataframe
    for idx, row in dataframe.iterrows():
        # Extract the list of items for the current row including duplicates
        
        item_list = row[dict_column]
        
        package_index = 0
        
        # Iterate through each item in the list
        for item_name in item_list:
            # Skip 'Lottie and Jigglypuff'
            if item_name == 'Lottie and Jigglypuff':
                continue
            else:
             # Find item information in inventory list
                item_info = next((item for item in inventory if item.name == item_name), None)
                package_index += 1
                
                # If item information is found
                if item_info:
                # Increment package index
                    if package_index == 1:
                        dataframe.at[idx, f"Parcel Contents - Description"] = item_info.description
                        dataframe.at[idx, f"Parcel Contents - Weight"] = item_info.weight
                        dataframe.at[idx, f"Parcel Contents - Value"] = item_info.value
                        dataframe.at[idx, f"Parcel Contents - Quantity"] = "1"
                        dataframe.at[idx, f"Parcel Contents - Country Of Origin"] = "AU"
                        dataframe.at[idx, f"Parcel Contents - HS Tariff"] = item_info.hs_tariff
                # Fill package contents columns with item information
                    else:
                        dataframe.at[idx, f"Parcel {package_index} Contents - Description"] = item_info.description
                        dataframe.at[idx, f"Parcel {package_index} Contents - Weight"] = item_info.weight
                        dataframe.at[idx, f"Parcel {package_index} Contents - Value"] = item_info.value
                        dataframe.at[idx, f"Parcel {package_index} Contents - Quantity"] = '1'
                        dataframe.at[idx, f"Parcel {package_index} Contents - Country Of Origin"] = "AU"
                        dataframe.at[idx, f"Parcel {package_index} Contents - HS Tariff"] = item_info.hs_tariff
    return dataframe

# %%
final_df = defining_package(relevant_df, inventory, 'cart')

# %%
# Keeping only columns relevant to Auspost
columns = ['Send From Name', 'Send From Business Name', 'Send From Address Line 1',
         'Send From Address Line 2','Send From Address Line 3','Send From Suburb',
         'Send From State','Send From Postcode', 'Send From Phone Number', 'Send From Email Address',
         'Deliver To Name',
         'Deliver To Type Of Address', 'Deliver To Country', 'Deliver To Address Line 1',
         'Deliver To Address Line 2', 'Deliver To Address Line 3','Deliver To Suburb',
         'Deliver To State', 'Deliver To Postcode', 'Deliver To Phone Number',
         'Deliver To Email Address', 'Item Packaging Type', 'Item Delivery Service', 
         'Item Description', 'Item Length', 'Item Width',
         'Item Height', 'Item Weight', 'Item Dangerous Goods Flag', 'Signature On Delivery',
         'Extra Cover Amount', 'Cannot Be Delivered - Return To Sender / Abandon Parcel', 
         'Customs Declaration - Commercial Value', 'Customs Declaration - Reason For Export', 
         'Customs Declaration - Why Are You Exporting These Goods', 'Export Declaration Number', 
         'SMS Tracking Notifications', 'SMS Tracking Mobile Phone', 'Send Tracking Notifications',
         'Send Tracking Email', 'Additional Label Information 1', 'Delivery Instructions',
         'Comments', "Importer's Reference Number", 'Licence Numbers',
         'Certificate Numbers', 'Invoice Numbers']

parcel_columns = [col for col in final_df.columns if col.startswith('Parcel')]
all_cols = columns + parcel_columns 
save = final_df[all_cols]

# %%
save.to_csv('upload_this.csv')
