# %%
import pandas as pd, numpy as np, csv
import requests
import json
from datetime import datetime, timezone

# %%
# Getting time
current_time_utc = datetime.now(timezone.utc)
formatted_time = current_time_utc.strftime('%Y-%m-%dT%H:%M:%SZ')

# Using API to retrieve pending orders
url = f"https://api.squarespace.com/1.0/commerce/orders?modifiedBefore={formatted_time}&modifiedAfter=2023-01-01T01:00:00Z&fulfillmentStatus={'PENDING'}"
headers = {
    "Authorization": "Bearer 4d00ecf2-edd8-4cf4-a4e0-cff6c7917691",
    "User-Agent": "me..",
    "Content-Type": "application/json"
}

response = requests.get(url, headers = headers)

# Confirming 
if response.status_code == 200:
    print('Success')
elif response.status_code == 204:
    print('No content')
else:
    print('Error')
# Out:
# Success

# %%
# Compiling as dataframe
pending_df = pd.json_normalize(response.json(), 'result')

# %%
# Taking relevant information
relevant_df = pending_df[['orderNumber','createdOn', 'customerEmail', 'shippingAddress.firstName', 
                          'shippingAddress.lastName', 'shippingAddress.address1', 'shippingAddress.address2', 
                          'shippingAddress.city', 'shippingAddress.state', 'shippingAddress.countryCode', 
                          'shippingAddress.postalCode', 'shippingAddress.phone', 'lineItems','subtotal.value', 
                          ]].copy()

# %%
## Assessing phone number
def clean_phone(x):
    x = x.replace("'", "")
    x = x.replace(" ", "")
    x = x.replace("\+61", "0")
    x = x.replace("nan", "")
    
    if x.startswith('04') == False or len(x) < 10:
        x = np.nan
    else:
        x = x
    
    return x

# %%
## Assessing delivery type based on country
def int_or_dom_service(country):
    if country == 'AU':
        return 'PP'
    else:
        return 'STD'

# %%
# Initialize a dictionary to store item classes
class Item:
    def __init__(self, name, length, width, height, weight, material, description, hs_tarrif, value):
        self.name = name
        self.length = length
        self.width = width
        self.height = height
        self.weight = weight
        self.material = material
        self.description = description
        self.hs_tariff = hs_tarrif
        self.value = value
        
    
inventory = []
# Replace 'your_file.csv' with the path to your CSV file
with open('inventory_properties.csv', 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    # Skip the header row if it exists
    next(csv_reader, None)

    for row in csv_reader:
        # Item	Length	Width	Height	Weight	Material	Description	Hs tarrif value
        item = Item(str(row[0]), str(row[1]), str(row[2]), str(row[3]), str(row[4]), 
                    str(row[5]), str(row[6]), str(row[7]), str(row[8]))
        inventory.append(item)
        
# Gathering package properties 
def package_properties(package_contents):
        length = 0
        width = 0
        height = 0
        weight = 0
        description = []
        
        for element in package_contents:
            for item in inventory:
                if item.name == element:                 # If the item in the order matches the name in the inventory list
                    height += float(item.height)           # Sum it's height
                    weight += float(item.weight)            # ... it's weight
                
                    if length < float(item.length):        # take the largest length
                        length = float(item.length)        
                    if width < float(item.width):          # and the widest width
                        width = float(item.width)           
                    description.append(str(item.description)) # and adds the item to the package description
        
        return length, width, height, weight, description

# %%
# Extending dataframe to explicitly write the shipping address

# Shipping variables
relevant_df.rename(columns={'shippingAddress.address1': 'Deliver To Address Line 1',
                            'shippingAddress.address2': 'Deliver To Address Line 2',
                            'shippingAddress.city': 'Deliver To Suburb',
                            'shippingAddress.state': 'Deliver To State',
                            'shippingAddress.postalCode': 'Deliver To Postcode',
                            'shippingAddress.phone': 'Deliver To Phone Number',
                            'shippingAddress.countryCode': 'Deliver To Country',
                            'customerEmail' : 'Deliver To Email Address'
                           }, inplace=True)
relevant_df["Deliver To Address Line 3"] = np.nan
relevant_df["Deliver To Phone Number"] = relevant_df['Deliver To Phone Number'].astype(str).apply(lambda x: clean_phone(x))
relevant_df['Deliver To Name'] = relevant_df['shippingAddress.firstName'] + " " + relevant_df['shippingAddress.lastName']

# Seller variables
relevant_df["Send From Name"] = "Chloe Hayden ltd pty"
relevant_df["Send From Business Name"] = "Chloe Hayden"
relevant_df["Send From Address Line 1"] = "PO BOX 137"
relevant_df["Send From Address Line 2"] = np.nan
relevant_df["Send From Address Line 3"] = np.nan
relevant_df["Send From Suburb"] = "Inverleigh"
relevant_df["Send From State"] = "VIC"
relevant_df["Send From Postcode"] = "3321"
relevant_df["Send From Phone Number"] = np.nan
relevant_df["Send From Email Address"] = "chloehaydensmerch@gmail.com"



# Label variables
relevant_df["Send Tracking Notifications"] = "NO"
relevant_df["Send Tracking Email"] =  "NO"
relevant_df["Additional Label Information 1"] = np.nan
relevant_df["Delivery Instructions"] = np.nan
relevant_df["Comments"] = "Thank You! :)"
relevant_df["Importer's Reference Number"] = np.nan
relevant_df["Licence Numbers"] = np.nan
relevant_df["Certificate Numbers"] = np.nan
relevant_df["Invoice Numbers"] = np.nan

# Package variables
relevant_df["Item Delivery Service"] = relevant_df["Deliver To Country"].apply(lambda x: int_or_dom_service(x))
relevant_df["Item Packaging Type"] = 'OWN_PACKAGING'
relevant_df["Item Dangerous Goods Flag"] = 'NO'

# Set variables - other
relevant_df["Signature On Delivery"] = 'NO'
relevant_df["Extra Cover Amount"] = np.nan
relevant_df["Cannot Be Delivered - Return To Sender / Abandon Parcel"] = 'RETURN'
relevant_df["Customs Declaration - Commercial Value"] = "YES"
relevant_df["Customs Declaration - Reason For Export"] = 'SALE_OF_GOODS'
relevant_df["Customs Declaration - Why Are You Exporting These Goods"] = 'Delivery to Customers address'
relevant_df["Export Declaration Number"] = np.nan
relevant_df["SMS Tracking Notifications"] = 'NO'
relevant_df["SMS Tracking Mobile Phone"] = np.nan
relevant_df["Deliver To MyPost Number"] = np.nan
relevant_df["Deliver To Business Name"] = np.nan
relevant_df["Deliver To Type Of Address"] = np.nan

# %%
# Obtaining cart info
def cart_contents(order_id, dataframe):
    order = relevant_df[relevant_df['orderNumber'] == order_id]
    cart = []
    for element in order['lineItems']:
        for item in range(0, len(element)):
            quantity = element[item].get('quantity')
            for n in range(0, quantity):
                cart.append(element[item].get('productName'))
    return cart

# %%
## Obtaining cart info as a dictionary
#def cart_contents(order_id, dataframe):
#    order = relevant_df[relevant_df['orderNumber'] == order_id]
#    cart = {}
#    for element in order['lineItems']:
#        for item in range(0, len(element)):
#            cart[element[item].get('productName')] = element[item].get('quantity')
#    return cart
#        
#    # use this test code to finish next section (order summary)
#cart_contents('2021', relevant_df)

# %%
# Creating column to hold new dictionary
relevant_df["cart"] = relevant_df["orderNumber"].map(lambda x: cart_contents(x, relevant_df))

# %%
# Create new columns in the orders_df DataFrame
relevant_df['Item Length'] = relevant_df['cart'].apply(lambda x: package_properties(x)[0])
relevant_df['Item Width'] = relevant_df['cart'].apply(lambda x: package_properties(x)[1])
relevant_df['Item Height'] = relevant_df['cart'].apply(lambda x: package_properties(x)[2])
relevant_df['Item Weight'] = relevant_df['cart'].apply(lambda x: package_properties(x)[3])
relevant_df['Item Description'] = relevant_df['cart'].apply(lambda x: f"You are expecting {len(x)} item/s")

# %%
# Looking for largest order
max_items = 0
for x in relevant_df['lineItems']:
    if len(x) > max_items:
        max_items = len(x)

# Appending individual items
def defining_package(dataframe, inventory, dict_column):
    # Iterate through each row in dataframe
    for idx, row in dataframe.iterrows():
        # Extract the list of items for the current row including duplicates
        
        item_list = row[dict_column]
        
        package_index = 0
        
        # Iterate through each item in the list
        for item_name in item_list:
            # Skip 'Lottie and Jigglypuff'
            if item_name == 'Lottie and Jigglypuff':
                continue
            else:
             # Find item information in inventory list
                item_info = next((item for item in inventory if item.name == item_name), None)
                package_index += 1
                
                # If item information is found
                if item_info:
                # Increment package index
                    if package_index == 1:
                        dataframe.at[idx, f"Parcel Contents - Description"] = item_info.description
                        dataframe.at[idx, f"Parcel Contents - Weight"] = item_info.weight
                        dataframe.at[idx, f"Parcel Contents - Value"] = item_info.value
                        dataframe.at[idx, f"Parcel Contents - Quantity"] = "1"
                        dataframe.at[idx, f"Parcel Contents - Country Of Origin"] = "AU"
                        dataframe.at[idx, f"Parcel Contents - HS Tariff"] = item_info.hs_tariff
                # Fill package contents columns with item information
                    else:
                        dataframe.at[idx, f"Parcel {package_index} Contents - Description"] = item_info.description
                        dataframe.at[idx, f"Parcel {package_index} Contents - Weight"] = item_info.weight
                        dataframe.at[idx, f"Parcel {package_index} Contents - Value"] = item_info.value
                        dataframe.at[idx, f"Parcel {package_index} Contents - Quantity"] = '1'
                        dataframe.at[idx, f"Parcel {package_index} Contents - Country Of Origin"] = "AU"
                        dataframe.at[idx, f"Parcel {package_index} Contents - HS Tariff"] = item_info.hs_tariff
    return dataframe

# %%
final_df = defining_package(relevant_df, inventory, 'cart')

# %%
# Keeping only columns relevant to Auspost
columns = ['Send From Name', 'Send From Business Name', 'Send From Address Line 1',
         'Send From Address Line 2','Send From Address Line 3','Send From Suburb',
         'Send From State','Send From Postcode', 'Send From Phone Number', 'Send From Email Address',
         'Deliver To Name',
         'Deliver To Type Of Address', 'Deliver To Country', 'Deliver To Address Line 1',
         'Deliver To Address Line 2', 'Deliver To Address Line 3','Deliver To Suburb',
         'Deliver To State', 'Deliver To Postcode', 'Deliver To Phone Number',
         'Deliver To Email Address', 'Item Packaging Type', 'Item Delivery Service', 
         'Item Description', 'Item Length', 'Item Width',
         'Item Height', 'Item Weight', 'Item Dangerous Goods Flag', 'Signature On Delivery',
         'Extra Cover Amount', 'Cannot Be Delivered - Return To Sender / Abandon Parcel', 
         'Customs Declaration - Commercial Value', 'Customs Declaration - Reason For Export', 
         'Customs Declaration - Why Are You Exporting These Goods', 'Export Declaration Number', 
         'SMS Tracking Notifications', 'SMS Tracking Mobile Phone', 'Send Tracking Notifications',
         'Send Tracking Email', 'Additional Label Information 1', 'Delivery Instructions',
         'Comments', "Importer's Reference Number", 'Licence Numbers',
         'Certificate Numbers', 'Invoice Numbers']

parcel_columns = [col for col in final_df.columns if col.startswith('Parcel')]
all_cols = columns + parcel_columns 
save = final_df[all_cols]

# %%
save.to_csv('upload_this.csv')
pd.set_option('display.max_columns', None)
save
# Out:
#           Send From Name Send From Business Name Send From Address Line 1  \
# 0   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 1   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 2   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 3   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 4   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 5   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 6   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 7   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 8   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 9   Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 10  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 11  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 12  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 13  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 14  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 15  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 16  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 17  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 18  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 19  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
# 20  Chloe Hayden ltd pty            Chloe Hayden               PO BOX 137
#
#     Send From Address Line 2  Send From Address Line 3 Send From Suburb  \
# 0                        NaN                       NaN       Inverleigh
# 1                        NaN                       NaN       Inverleigh
# 2                        NaN                       NaN       Inverleigh
# 3                        NaN                       NaN       Inverleigh
# 4                        NaN                       NaN       Inverleigh
# 5                        NaN                       NaN       Inverleigh
# 6                        NaN                       NaN       Inverleigh
# 7                        NaN                       NaN       Inverleigh
# 8                        NaN                       NaN       Inverleigh
# 9                        NaN                       NaN       Inverleigh
# 10                       NaN                       NaN       Inverleigh
# 11                       NaN                       NaN       Inverleigh
# 12                       NaN                       NaN       Inverleigh
# 13                       NaN                       NaN       Inverleigh
# 14                       NaN                       NaN       Inverleigh
# 15                       NaN                       NaN       Inverleigh
# 16                       NaN                       NaN       Inverleigh
# 17                       NaN                       NaN       Inverleigh
# 18                       NaN                       NaN       Inverleigh
# 19                       NaN                       NaN       Inverleigh
# 20                       NaN                       NaN       Inverleigh
#
#    Send From State Send From Postcode  Send From Phone Number  \
# 0              VIC               3321                     NaN
# 1              VIC               3321                     NaN
# 2              VIC               3321                     NaN
# 3              VIC               3321                     NaN
# 4              VIC               3321                     NaN
# 5              VIC               3321                     NaN
# 6              VIC               3321                     NaN
# 7              VIC               3321                     NaN
# 8              VIC               3321                     NaN
# 9              VIC               3321                     NaN
# 10             VIC               3321                     NaN
# 11             VIC               3321                     NaN
# 12             VIC               3321                     NaN
# 13             VIC               3321                     NaN
# 14             VIC               3321                     NaN
# 15             VIC               3321                     NaN
# 16             VIC               3321                     NaN
# 17             VIC               3321                     NaN
# 18             VIC               3321                     NaN
# 19             VIC               3321                     NaN
# 20             VIC               3321                     NaN
#
#         Send From Email Address       Deliver To Name  \
# 0   chloehaydensmerch@gmail.com        Isabella Milne
# 1   chloehaydensmerch@gmail.com         Linda Jenkins
# 2   chloehaydensmerch@gmail.com           Fiona Keele
# 3   chloehaydensmerch@gmail.com         Molly Roberts
# 4   chloehaydensmerch@gmail.com       Brookie Hamence
# 5   chloehaydensmerch@gmail.com        Nicole McGrady
# 6   chloehaydensmerch@gmail.com       Sarah Jenkinson
# 7   chloehaydensmerch@gmail.com          Katina Ayoub
# 8   chloehaydensmerch@gmail.com           Drew Nugent
# 9   chloehaydensmerch@gmail.com            Steph Dent
# 10  chloehaydensmerch@gmail.com             Jana Dutz
# 11  chloehaydensmerch@gmail.com           Emma Knight
# 12  chloehaydensmerch@gmail.com      Josef Garrington
# 13  chloehaydensmerch@gmail.com      Hayley Hawrylciw
# 14  chloehaydensmerch@gmail.com        Mikayla Martin
# 15  chloehaydensmerch@gmail.com       Charlie Jenkins
# 16  chloehaydensmerch@gmail.com  Amelie Blondin-Bayly
# 17  chloehaydensmerch@gmail.com        Isabel Fooskas
# 18  chloehaydensmerch@gmail.com          Amber Morris
# 19  chloehaydensmerch@gmail.com        Mary Samuelson
# 20  chloehaydensmerch@gmail.com          Sasha Ferris
#
#     Deliver To Type Of Address Deliver To Country Deliver To Address Line 1  \
# 0                          NaN                 AU           17 Coral Avenue
# 1                          NaN                 AU         5 Belvedere Court
# 2                          NaN                 AU         23 McSwain Street
# 3                          NaN                 AU          10 Readshaw Road
# 4                          NaN                 AU      U 7/370a Eleventh St
# 5                          NaN                 GB           23 Grove Street
# 6                          NaN                 AU             10 Auburn Pde
# 7                          NaN                 AU           28 Perry Street
# 8                          NaN                 AU           24 Cambridge St
# 9                          NaN                 AU               PO Box 1234
# 10                         NaN                 DE           20 Pilotystraße
# 11                         NaN                 AU             5 Musgrave St
# 12                         NaN                 AU          19-23 Stewart St
# 13                         NaN                 AU           38 Cannery Road
# 14                         NaN                 AU         10 Bastow Circuit
# 15                         NaN                 GB       8 Cromwell Crescent
# 16                         NaN                 AU                        53
# 17                         NaN                 US         205 Woodward Road
# 18                         NaN                 AU          56 Middle Street
# 19                         NaN                 US            480 Commons Dr
# 20                         NaN                 AU       135 Bellevue Street
#
#    Deliver To Address Line 2  Deliver To Address Line 3 Deliver To Suburb  \
# 0                       None                        NaN         Footscray
# 1                       None                        NaN  Moore Park Beach
# 2                       None                        NaN          Parkdale
# 3                       None                        NaN          Duncraig
# 4                       None                        NaN           Mildura
# 5                  Balderton                        NaN            Newark
# 6                       None                        NaN     Hawthorn East
# 7                       None                        NaN        Matraville
# 8                  Cambridge                        NaN           ROZELLE
# 9          Peramangk Country                        NaN            Nairne
# 10                      None                        NaN          Nürnberg
# 11                      None                        NaN          Goodwood
# 12                        13                        NaN             Glebe
# 13                      None                        NaN          Plumpton
# 14                      None                        NaN             Banks
# 15                      None                        NaN        Pontefract
# 16              Cuzco Strest                        NaN      South Coogee
# 17                      None                        NaN             Media
# 18            McMahons Point                        NaN            Sydney
# 19                  Apt 2112                        NaN          Burleson
# 20                      None                        NaN          CAMMERAY
#
#    Deliver To State Deliver To Postcode Deliver To Phone Number  \
# 0               VIC                3011              0412224395
# 1               QLD                4670              0416173325
# 2              None                3195              0407978711
# 3                WA                6023              0423478487
# 4               VIC                3500              0429211333
# 5   Nottinghamshire            NG24 3AR                     NaN
# 6               VIC                3123                     NaN
# 7               NSW                2036              0422885811
# 8               NSW                2039              0423941905
# 9                SA                5252              0421958471
# 10               BY               90408                     NaN
# 11               SA                5034                     NaN
# 12              NSW                2037                     NaN
# 13              NSW                2761              0417620589
# 14              ACT                2906              0424604518
# 15          England             WF8 2EG                     NaN
# 16              NSW                2034                     NaN
# 17               PA               19063                     NaN
# 18              NSW                2060                     NaN
# 19               TX               76028                     NaN
# 20              NSW                2062              0457686266
#
#             Deliver To Email Address Item Packaging Type  \
# 0           isabellamilne@y7mail.com       OWN_PACKAGING
# 1               lindap82@hotmail.com       OWN_PACKAGING
# 2               fi_scott@hotmail.com       OWN_PACKAGING
# 3         molly.roberts1@hotmail.com       OWN_PACKAGING
# 4           dramaqueenbh23@gmail.com       OWN_PACKAGING
# 5              n.mcgrady@hotmail.com       OWN_PACKAGING
# 6       sarah.li.jenkinson@gmail.com       OWN_PACKAGING
# 7            kat.tsangaris@gmail.com       OWN_PACKAGING
# 8               valooo1998@gmail.com       OWN_PACKAGING
# 9   steph.graves61@schools.sa.edu.au       OWN_PACKAGING
# 10              katzekarla@ymail.com       OWN_PACKAGING
# 11             emmakathome@gmail.com       OWN_PACKAGING
# 12         josefgarrington@gmail.com       OWN_PACKAGING
# 13      hayleyhawrylciw@yahoo.com.au       OWN_PACKAGING
# 14       mikaylamartin2498@gmail.com       OWN_PACKAGING
# 15       charlie.jenkins@zohomail.eu       OWN_PACKAGING
# 16           amelie.rose99@gmail.com       OWN_PACKAGING
# 17           isabelfooskas@gmail.com       OWN_PACKAGING
# 18               amber@salted.com.au       OWN_PACKAGING
# 19     maryashleysamuelson@gmail.com       OWN_PACKAGING
# 20              sashtag135@gmail.com       OWN_PACKAGING
#
#    Item Delivery Service            Item Description  Item Length  Item Width  \
# 0                     PP  You are expecting 1 item/s         15.0        15.0
# 1                     PP  You are expecting 2 item/s         15.0        15.0
# 2                     PP  You are expecting 1 item/s         15.0        15.0
# 3                     PP  You are expecting 1 item/s         15.0        15.0
# 4                     PP  You are expecting 2 item/s         15.0        15.0
# 5                    STD  You are expecting 2 item/s         15.0        15.0
# 6                     PP  You are expecting 1 item/s         15.0        15.0
# 7                     PP  You are expecting 2 item/s         15.0        15.0
# 8                     PP  You are expecting 3 item/s         26.5        15.0
# 9                     PP  You are expecting 1 item/s         15.0        15.0
# 10                   STD  You are expecting 2 item/s         15.0        15.0
# 11                    PP  You are expecting 3 item/s         15.0        15.0
# 12                    PP  You are expecting 2 item/s         15.0        15.0
# 13                    PP  You are expecting 3 item/s         26.5        30.0
# 14                    PP  You are expecting 1 item/s         15.0        15.0
# 15                   STD  You are expecting 2 item/s         15.0        15.0
# 16                    PP  You are expecting 1 item/s         15.0        15.0
# 17                   STD  You are expecting 2 item/s         15.0        15.0
# 18                    PP  You are expecting 2 item/s         15.0        15.0
# 19                   STD  You are expecting 1 item/s         15.0        15.0
# 20                    PP  You are expecting 1 item/s         15.0        15.0
#
#     Item Height  Item Weight Item Dangerous Goods Flag Signature On Delivery  \
# 0           1.0         0.35                        NO                    NO
# 1           4.0         0.31                        NO                    NO
# 2           1.0         0.01                        NO                    NO
# 3           1.0         0.01                        NO                    NO
# 4           2.0         0.02                        NO                    NO
# 5           4.0         0.27                        NO                    NO
# 6           1.0         0.01                        NO                    NO
# 7           4.0         0.27                        NO                    NO
# 8           2.0         0.05                        NO                    NO
# 9           1.0         0.01                        NO                    NO
# 10          5.0         0.12                        NO                    NO
# 11          5.0         0.28                        NO                    NO
# 12          4.0         0.27                        NO                    NO
# 13          9.0         0.96                        NO                    NO
# 14          1.0         0.01                        NO                    NO
# 15          4.0         0.31                        NO                    NO
# 16          1.0         0.01                        NO                    NO
# 17          4.0         0.27                        NO                    NO
# 18          5.0         0.12                        NO                    NO
# 19          1.0         0.01                        NO                    NO
# 20          1.0         0.01                        NO                    NO
#
#     Extra Cover Amount  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
#
#    Cannot Be Delivered - Return To Sender / Abandon Parcel  \
# 0                                              RETURN
# 1                                              RETURN
# 2                                              RETURN
# 3                                              RETURN
# 4                                              RETURN
# 5                                              RETURN
# 6                                              RETURN
# 7                                              RETURN
# 8                                              RETURN
# 9                                              RETURN
# 10                                             RETURN
# 11                                             RETURN
# 12                                             RETURN
# 13                                             RETURN
# 14                                             RETURN
# 15                                             RETURN
# 16                                             RETURN
# 17                                             RETURN
# 18                                             RETURN
# 19                                             RETURN
# 20                                             RETURN
#
#    Customs Declaration - Commercial Value  \
# 0                                     YES
# 1                                     YES
# 2                                     YES
# 3                                     YES
# 4                                     YES
# 5                                     YES
# 6                                     YES
# 7                                     YES
# 8                                     YES
# 9                                     YES
# 10                                    YES
# 11                                    YES
# 12                                    YES
# 13                                    YES
# 14                                    YES
# 15                                    YES
# 16                                    YES
# 17                                    YES
# 18                                    YES
# 19                                    YES
# 20                                    YES
#
#    Customs Declaration - Reason For Export  \
# 0                            SALE_OF_GOODS
# 1                            SALE_OF_GOODS
# 2                            SALE_OF_GOODS
# 3                            SALE_OF_GOODS
# 4                            SALE_OF_GOODS
# 5                            SALE_OF_GOODS
# 6                            SALE_OF_GOODS
# 7                            SALE_OF_GOODS
# 8                            SALE_OF_GOODS
# 9                            SALE_OF_GOODS
# 10                           SALE_OF_GOODS
# 11                           SALE_OF_GOODS
# 12                           SALE_OF_GOODS
# 13                           SALE_OF_GOODS
# 14                           SALE_OF_GOODS
# 15                           SALE_OF_GOODS
# 16                           SALE_OF_GOODS
# 17                           SALE_OF_GOODS
# 18                           SALE_OF_GOODS
# 19                           SALE_OF_GOODS
# 20                           SALE_OF_GOODS
#
#    Customs Declaration - Why Are You Exporting These Goods  \
# 0                       Delivery to Customers address
# 1                       Delivery to Customers address
# 2                       Delivery to Customers address
# 3                       Delivery to Customers address
# 4                       Delivery to Customers address
# 5                       Delivery to Customers address
# 6                       Delivery to Customers address
# 7                       Delivery to Customers address
# 8                       Delivery to Customers address
# 9                       Delivery to Customers address
# 10                      Delivery to Customers address
# 11                      Delivery to Customers address
# 12                      Delivery to Customers address
# 13                      Delivery to Customers address
# 14                      Delivery to Customers address
# 15                      Delivery to Customers address
# 16                      Delivery to Customers address
# 17                      Delivery to Customers address
# 18                      Delivery to Customers address
# 19                      Delivery to Customers address
# 20                      Delivery to Customers address
#
#     Export Declaration Number SMS Tracking Notifications  \
# 0                         NaN                         NO
# 1                         NaN                         NO
# 2                         NaN                         NO
# 3                         NaN                         NO
# 4                         NaN                         NO
# 5                         NaN                         NO
# 6                         NaN                         NO
# 7                         NaN                         NO
# 8                         NaN                         NO
# 9                         NaN                         NO
# 10                        NaN                         NO
# 11                        NaN                         NO
# 12                        NaN                         NO
# 13                        NaN                         NO
# 14                        NaN                         NO
# 15                        NaN                         NO
# 16                        NaN                         NO
# 17                        NaN                         NO
# 18                        NaN                         NO
# 19                        NaN                         NO
# 20                        NaN                         NO
#
#     SMS Tracking Mobile Phone Send Tracking Notifications Send Tracking Email  \
# 0                         NaN                          NO                  NO
# 1                         NaN                          NO                  NO
# 2                         NaN                          NO                  NO
# 3                         NaN                          NO                  NO
# 4                         NaN                          NO                  NO
# 5                         NaN                          NO                  NO
# 6                         NaN                          NO                  NO
# 7                         NaN                          NO                  NO
# 8                         NaN                          NO                  NO
# 9                         NaN                          NO                  NO
# 10                        NaN                          NO                  NO
# 11                        NaN                          NO                  NO
# 12                        NaN                          NO                  NO
# 13                        NaN                          NO                  NO
# 14                        NaN                          NO                  NO
# 15                        NaN                          NO                  NO
# 16                        NaN                          NO                  NO
# 17                        NaN                          NO                  NO
# 18                        NaN                          NO                  NO
# 19                        NaN                          NO                  NO
# 20                        NaN                          NO                  NO
#
#     Additional Label Information 1  Delivery Instructions       Comments  \
# 0                              NaN                    NaN  Thank You! :)
# 1                              NaN                    NaN  Thank You! :)
# 2                              NaN                    NaN  Thank You! :)
# 3                              NaN                    NaN  Thank You! :)
# 4                              NaN                    NaN  Thank You! :)
# 5                              NaN                    NaN  Thank You! :)
# 6                              NaN                    NaN  Thank You! :)
# 7                              NaN                    NaN  Thank You! :)
# 8                              NaN                    NaN  Thank You! :)
# 9                              NaN                    NaN  Thank You! :)
# 10                             NaN                    NaN  Thank You! :)
# 11                             NaN                    NaN  Thank You! :)
# 12                             NaN                    NaN  Thank You! :)
# 13                             NaN                    NaN  Thank You! :)
# 14                             NaN                    NaN  Thank You! :)
# 15                             NaN                    NaN  Thank You! :)
# 16                             NaN                    NaN  Thank You! :)
# 17                             NaN                    NaN  Thank You! :)
# 18                             NaN                    NaN  Thank You! :)
# 19                             NaN                    NaN  Thank You! :)
# 20                             NaN                    NaN  Thank You! :)
#
#     Importer's Reference Number  Licence Numbers  Certificate Numbers  \
# 0                           NaN              NaN                  NaN
# 1                           NaN              NaN                  NaN
# 2                           NaN              NaN                  NaN
# 3                           NaN              NaN                  NaN
# 4                           NaN              NaN                  NaN
# 5                           NaN              NaN                  NaN
# 6                           NaN              NaN                  NaN
# 7                           NaN              NaN                  NaN
# 8                           NaN              NaN                  NaN
# 9                           NaN              NaN                  NaN
# 10                          NaN              NaN                  NaN
# 11                          NaN              NaN                  NaN
# 12                          NaN              NaN                  NaN
# 13                          NaN              NaN                  NaN
# 14                          NaN              NaN                  NaN
# 15                          NaN              NaN                  NaN
# 16                          NaN              NaN                  NaN
# 17                          NaN              NaN                  NaN
# 18                          NaN              NaN                  NaN
# 19                          NaN              NaN                  NaN
# 20                          NaN              NaN                  NaN
#
#     Invoice Numbers Parcel Contents - Description Parcel Contents - Weight  \
# 0               NaN                Self help book                     0.35
# 1               NaN                Pinback button                     0.01
# 2               NaN                Pinback button                     0.01
# 3               NaN                Pinback button                     0.01
# 4               NaN                Pinback button                     0.01
# 5               NaN                       T-shirt                     0.26
# 6               NaN                Pinback button                     0.01
# 7               NaN                Pinback button                     0.01
# 8               NaN                Pinback button                     0.01
# 9               NaN                Pinback button                     0.01
# 10              NaN                        Beanie                     0.11
# 11              NaN                       T-shirt                     0.26
# 12              NaN                Pinback button                     0.01
# 13              NaN                Pinback button                     0.01
# 14              NaN                Pinback button                     0.01
# 15              NaN                       T-shirt                      0.3
# 16              NaN                Pinback button                     0.01
# 17              NaN                       T-shirt                     0.26
# 18              NaN                Pinback button                     0.01
# 19              NaN                Pinback button                     0.01
# 20              NaN                Pinback button                     0.01
#
#    Parcel Contents - Value Parcel Contents - Quantity  \
# 0                       15                          1
# 1                       20                          1
# 2                       20                          1
# 3                       20                          1
# 4                       15                          1
# 5                       45                          1
# 6                       20                          1
# 7                       20                          1
# 8                       20                          1
# 9                       20                          1
# 10                      35                          1
# 11                      45                          1
# 12                      20                          1
# 13                      20                          1
# 14                      20                          1
# 15                      45                          1
# 16                      20                          1
# 17                      45                          1
# 18                      20                          1
# 19                      20                          1
# 20                      20                          1
#
#    Parcel Contents - Country Of Origin Parcel Contents - HS Tariff  \
# 0                                   AU                      490199
# 1                                   AU                      960622
# 2                                   AU                      960622
# 3                                   AU                      960622
# 4                                   AU                      960622
# 5                                   AU                      610910
# 6                                   AU                      960622
# 7                                   AU                      960622
# 8                                   AU                      960622
# 9                                   AU                      960622
# 10                                  AU                      650500
# 11                                  AU                      610910
# 12                                  AU                      960622
# 13                                  AU                      960622
# 14                                  AU                      960622
# 15                                  AU                      610910
# 16                                  AU                      960622
# 17                                  AU                      610910
# 18                                  AU                      960622
# 19                                  AU                      960622
# 20                                  AU                      960622
#
#    Parcel 2 Contents - Description Parcel 2 Contents - Weight  \
# 0                              NaN                        NaN
# 1                          T-shirt                        0.3
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                   Pinback button                       0.01
# 5                   Pinback button                       0.01
# 6                              NaN                        NaN
# 7                          T-shirt                       0.26
# 8           Laptop sticker / decal                       0.02
# 9                              NaN                        NaN
# 10                  Pinback button                       0.01
# 11                  Pinback button                       0.01
# 12                         T-shirt                       0.26
# 13                          Hoodie                       0.65
# 14                             NaN                        NaN
# 15                  Pinback button                       0.01
# 16                             NaN                        NaN
# 17                  Pinback button                       0.01
# 18                          Beanie                       0.11
# 19                             NaN                        NaN
# 20                             NaN                        NaN
#
#    Parcel 2 Contents - Value Parcel 2 Contents - Quantity  \
# 0                        NaN                          NaN
# 1                         45                            1
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                         20                            1
# 5                         20                            1
# 6                        NaN                          NaN
# 7                         45                            1
# 8                       12.5                            1
# 9                        NaN                          NaN
# 10                        20                            1
# 11                        20                            1
# 12                        45                            1
# 13                        75                            1
# 14                       NaN                          NaN
# 15                        20                            1
# 16                       NaN                          NaN
# 17                        20                            1
# 18                        35                            1
# 19                       NaN                          NaN
# 20                       NaN                          NaN
#
#    Parcel 2 Contents - Country Of Origin Parcel 2 Contents - HS Tariff  \
# 0                                    NaN                           NaN
# 1                                     AU                        610910
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                     AU                        960622
# 5                                     AU                        960622
# 6                                    NaN                           NaN
# 7                                     AU                        610910
# 8                                     AU                        490810
# 9                                    NaN                           NaN
# 10                                    AU                        960622
# 11                                    AU                        960622
# 12                                    AU                        610910
# 13                                    AU                        611020
# 14                                   NaN                           NaN
# 15                                    AU                        960622
# 16                                   NaN                           NaN
# 17                                    AU                        960622
# 18                                    AU                        650500
# 19                                   NaN                           NaN
# 20                                   NaN                           NaN
#
#    Parcel 3 Contents - Description Parcel 3 Contents - Weight  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# 5                              NaN                        NaN
# 6                              NaN                        NaN
# 7                              NaN                        NaN
# 8           Laptop sticker / decal                       0.02
# 9                              NaN                        NaN
# 10                             NaN                        NaN
# 11                  Pinback button                       0.01
# 12                             NaN                        NaN
# 13                         T-shirt                        0.3
# 14                             NaN                        NaN
# 15                             NaN                        NaN
# 16                             NaN                        NaN
# 17                             NaN                        NaN
# 18                             NaN                        NaN
# 19                             NaN                        NaN
# 20                             NaN                        NaN
#
#    Parcel 3 Contents - Value Parcel 3 Contents - Quantity  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
# 5                        NaN                          NaN
# 6                        NaN                          NaN
# 7                        NaN                          NaN
# 8                       12.5                            1
# 9                        NaN                          NaN
# 10                       NaN                          NaN
# 11                        15                            1
# 12                       NaN                          NaN
# 13                        45                            1
# 14                       NaN                          NaN
# 15                       NaN                          NaN
# 16                       NaN                          NaN
# 17                       NaN                          NaN
# 18                       NaN                          NaN
# 19                       NaN                          NaN
# 20                       NaN                          NaN
#
#    Parcel 3 Contents - Country Of Origin Parcel 3 Contents - HS Tariff
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
# 5                                    NaN                           NaN
# 6                                    NaN                           NaN
# 7                                    NaN                           NaN
# 8                                     AU                        490810
# 9                                    NaN                           NaN
# 10                                   NaN                           NaN
# 11                                    AU                        960622
# 12                                   NaN                           NaN
# 13                                    AU                        610910
# 14                                   NaN                           NaN
# 15                                   NaN                           NaN
# 16                                   NaN                           NaN
# 17                                   NaN                           NaN
# 18                                   NaN                           NaN
# 19                                   NaN                           NaN
# 20                                   NaN                           NaN

# %%
pip install pyinstaller
# Out:
# Requirement already satisfied: pyinstaller in c:\users\dylan rohan\anaconda3\lib\site-packages (6.8.0)
# Requirement already satisfied: setuptools>=42.0.0 in c:\users\dylan rohan\anaconda3\lib\site-packages (from pyinstaller) (65.6.3)
# Requirement already satisfied: altgraph in c:\users\dylan rohan\anaconda3\lib\site-packages (from pyinstaller) (0.17.4)
# Requirement already satisfied: pyinstaller-hooks-contrib>=2024.6 in c:\users\dylan rohan\anaconda3\lib\site-packages (from pyinstaller) (2024.7)
# Requirement already satisfied: packaging>=22.0 in c:\users\dylan rohan\anaconda3\lib\site-packages (from pyinstaller) (22.0)
# Requirement already satisfied: pefile>=2022.5.30 in c:\users\dylan rohan\anaconda3\lib\site-packages (from pyinstaller) (2023.2.7)
# Requirement already satisfied: pywin32-ctypes>=0.2.1 in c:\users\dylan rohan\anaconda3\lib\site-packages (from pyinstaller) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyInstaller
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pyInstaller
#
# ModuleNotFoundError: No module named 'pyInstaller'
